# %%
import csv
import itertools
import operator
import numpy as np
import nltk
import sys
from datetime import datetime
#from utils import *

import matplotlib.pyplot as plt
# %matplotlib inline

import re
import string

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#nltk.download('book')

# %% [markdown]
# ***

# %%
vocabulary_size = 1500
unknown_token = 'UNKNOWN_TOKEN'
sentence_start_token = 'SENTENCE_START'
sentence_end_token = 'SENTENCE_END'

# %%
text = []
f = open('wizOfOz.txt', 'r')
#Read corpus into text as list of lines
ast_count = 0
for line in f.readlines():
    if ast_count == 0: #Gutenberg text
        if line[0] == '*':
            ast_count += 1
    elif ast_count == 1: #Book text
        if line[0] == '*': #Gutenberg text
            ast_count += 1
        else:
            text.append(line)
f.close()

#Form corpus by joining list of lines
corpus = ''.join(text)

#Remove line breaks and returns
corpus = corpus.replace('\n', ' ')
corpus = corpus.replace('\r', '')
corpus = corpus.replace('\\', '')

#Start from the introduction, the second occurrence of the word Introduction
iter = re.finditer(r'Introduction', corpus)
intro_indices = [m.start(0) for m in iter]
corp = corpus[intro_indices[1]:]

# %%
#Split corpus in to sentences
sentences = nltk.sent_tokenize(corp.decode('utf-8').lower())

# %%
sentences
# Out:
# [u'introduction   folklore, legends, myths and fairy tales have followed childhood through the ages, for every healthy youngster has a wholesome and instinctive love for stories fantastic, marvelous and manifestly unreal.',
#  u'the winged fairies of grimm and andersen have brought more happiness to childish hearts than all other human creations.',
#  u'yet the old time fairy tale, having served for generations, may now be classed as "historical" in the children\'s library; for the time has come for a series of newer "wonder tales" in which the stereotyped genie, dwarf and fairy are eliminated, together with all the horrible and blood-curdling incidents devised by their authors to point a fearsome moral to each tale.',
#  u'modern education includes morality; therefore the modern child seeks only entertainment in its wonder tales and gladly dispenses with all disagreeable incident.',
#  u'having this thought in mind, the story of "the wonderful wizard of oz" was written solely to please children of today.',
#  u'it aspires to being a modernized fairy tale, in which the wonderment and joy are retained and the heartaches and nightmares are left out.',
#  u"l. frank baum  chicago, april, 1900.     the wonderful wizard of oz     1.  the cyclone   dorothy lived in the midst of the great kansas prairies, with uncle henry, who was a farmer, and aunt em, who was the farmer's wife.",
#  u'their house was small, for the lumber to build it had to be carried by wagon many miles.',
#  u'there were four walls, a floor and a roof, which made one room; and this room contained a rusty looking cookstove, a cupboard for the dishes, a table, three or four chairs, and the beds.',
#  u'uncle henry and aunt em had a big bed in one corner, and dorothy a little bed in another corner.',
#  u'there was no garret at all, and no cellar--except a small hole dug in the ground, called a cyclone cellar, where the family could go in case one of those great whirlwinds arose, mighty enough to crush any building in its path.',
#  u'it was reached by a trap door in the middle of the floor, from which a ladder led down into the small, dark hole.',
#  u'when dorothy stood in the doorway and looked around, she could see nothing but the great gray prairie on every side.',
#  u'not a tree nor a house broke the broad sweep of flat country that reached to the edge of the sky in all directions.',
#  u'the sun had baked the plowed land into a gray mass, with little cracks running through it.',
#  u'even the grass was not green, for the sun had burned the tops of the long blades until they were the same gray color to be seen everywhere.',
#  u'once the house had been painted, but the sun blistered the paint and the rains washed it away, and now the house was as dull and gray as everything else.',
#  u'when aunt em came there to live she was a young, pretty wife.',
#  u'the sun and wind had changed her, too.',
#  u'they had taken the sparkle from her eyes and left them a sober gray; they had taken the red from her cheeks and lips, and they were gray also.',
#  u'she was thin and gaunt, and never smiled now.',
#  u"when dorothy, who was an orphan, first came to her, aunt em had been so startled by the child's laughter that she would scream and press her hand upon her heart whenever dorothy's merry voice reached her ears; and she still looked at the little girl with wonder that she could find anything to laugh at.",
#  u'uncle henry never laughed.',
#  u'he worked hard from morning till night and did not know what joy was.',
#  u'he was gray also, from his long beard to his rough boots, and he looked stern and solemn, and rarely spoke.',
#  u'it was toto that made dorothy laugh, and saved her from growing as gray as her other surroundings.',
#  u'toto was not gray; he was a little black dog, with long silky hair and small black eyes that twinkled merrily on either side of his funny, wee nose.',
#  u'toto played all day long, and dorothy played with him, and loved him dearly.',
#  u'today, however, they were not playing.',
#  u'uncle henry sat upon the doorstep and looked anxiously at the sky, which was even grayer than usual.',
#  u'dorothy stood in the door with toto in her arms, and looked at the sky too.',
#  u'aunt em was washing the dishes.',
#  u'from the far north they heard a low wail of the wind, and uncle henry and dorothy could see where the long grass bowed in waves before the coming storm.',
#  u'there now came a sharp whistling in the air from the south, and as they turned their eyes that way they saw ripples in the grass coming from that direction also.',
#  u'suddenly uncle henry stood up.',
#  u'"there\'s a cyclone coming, em," he called to his wife.',
#  u'"i\'ll go look after the stock."',
#  u'then he ran toward the sheds where the cows and horses were kept.',
#  u'aunt em dropped her work and came to the door.',
#  u'one glance told her of the danger close at hand.',
#  u'"quick, dorothy!"',
#  u'she screamed.',
#  u'"run for the cellar!"',
#  u"toto jumped out of dorothy's arms and hid under the bed, and the girl started to get him.",
#  u'aunt em, badly frightened, threw open the trap door in the floor and climbed down the ladder into the small, dark hole.',
#  u'dorothy caught toto at last and started to follow her aunt.',
#  u'when she was halfway across the room there came a great shriek from the wind, and the house shook so hard that she lost her footing and sat down suddenly upon the floor.',
#  u'then a strange thing happened.',
#  u'the house whirled around two or three times and rose slowly through the air.',
#  u'dorothy felt as if she were going up in a balloon.',
#  u'the north and south winds met where the house stood, and made it the exact center of the cyclone.',
#  u'in the middle of a cyclone the air is generally still, but the great pressure of the wind on every side of the house raised it up higher and higher, until it was at the very top of the cyclone; and there it remained and was carried miles and miles away as easily as you could carry a feather.',
#  u'it was very dark, and the wind howled horribly around her, but dorothy found she was riding quite easily.',
#  u'after the first few whirls around, and one other time when the house tipped badly, she felt as if she were being rocked gently, like a baby in a cradle.',
#  u'toto did not like it.',
#  u'he ran about the room, now here, now there, barking loudly; but dorothy sat quite still on the floor and waited to see what would happen.',
#  u'once toto got too near the open trap door, and fell in; and at first the little girl thought she had lost him.',
#  u'but soon she saw one of his ears sticking up through the hole, for the strong pressure of the air was keeping him up so that he could not fall.',
#  u'she crept to the hole, caught toto by the ear, and dragged him into the room again, afterward closing the trap door so that no more accidents could happen.',
#  u'hour after hour passed away, and slowly dorothy got over her fright; but she felt quite lonely, and the wind shrieked so loudly all about her that she nearly became deaf.',
#  u'at first she had wondered if she would be dashed to pieces when the house fell again; but as the hours passed and nothing terrible happened, she stopped worrying and resolved to wait calmly and see what the future would bring.',
#  u'at last she crawled over the swaying floor to her bed, and lay down upon it; and toto followed and lay down beside her.',
#  u'in spite of the swaying of the house and the wailing of the wind, dorothy soon closed her eyes and fell fast asleep.',
#  u'2.  the council with the munchkins   she was awakened by a shock, so sudden and severe that if dorothy had not been lying on the soft bed she might have been hurt.',
#  u'as it was, the jar made her catch her breath and wonder what had happened; and toto put his cold little nose into her face and whined dismally.',
#  u'dorothy sat up and noticed that the house was not moving; nor was it dark, for the bright sunshine came in at the window, flooding the little room.',
#  u'she sprang from her bed and with toto at her heels ran and opened the door.',
#  u'the little girl gave a cry of amazement and looked about her, her eyes growing bigger and bigger at the wonderful sights she saw.',
#  u'the cyclone had set the house down very gently--for a cyclone--in the midst of a country of marvelous beauty.',
#  u'there were lovely patches of greensward all about, with stately trees bearing rich and luscious fruits.',
#  u'banks of gorgeous flowers were on every hand, and birds with rare and brilliant plumage sang and fluttered in the trees and bushes.',
#  u'a little way off was a small brook, rushing and sparkling along between green banks, and murmuring in a voice very grateful to a little girl who had lived so long on the dry, gray prairies.',
#  u'while she stood looking eagerly at the strange and beautiful sights, she noticed coming toward her a group of the queerest people she had ever seen.',
#  u'they were not as big as the grown folk she had always been used to; but neither were they very small.',
#  u'in fact, they seemed about as tall as dorothy, who was a well-grown child for her age, although they were, so far as looks go, many years older.',
#  u'three were men and one a woman, and all were oddly dressed.',
#  u'they wore round hats that rose to a small point a foot above their heads, with little bells around the brims that tinkled sweetly as they moved.',
#  u"the hats of the men were blue; the little woman's hat was white, and she wore a white gown that hung in pleats from her shoulders.",
#  u'over it were sprinkled little stars that glistened in the sun like diamonds.',
#  u'the men were dressed in blue, of the same shade as their hats, and wore well-polished boots with a deep roll of blue at the tops.',
#  u'the men, dorothy thought, were about as old as uncle henry, for two of them had beards.',
#  u'but the little woman was doubtless much older.',
#  u'her face was covered with wrinkles, her hair was nearly white, and she walked rather stiffly.',
#  u'when these people drew near the house where dorothy was standing in the doorway, they paused and whispered among themselves, as if afraid to come farther.',
#  u'but the little old woman walked up to dorothy, made a low bow and said, in a sweet voice:  "you are welcome, most noble sorceress, to the land of the munchkins.',
#  u'we are so grateful to you for having killed the wicked witch of the east, and for setting our people free from bondage."',
#  u'dorothy listened to this speech with wonder.',
#  u'what could the little woman possibly mean by calling her a sorceress, and saying she had killed the wicked witch of the east?',
#  u'dorothy was an innocent, harmless little girl, who had been carried by a cyclone many miles from home; and she had never killed anything in all her life.',
#  u'but the little woman evidently expected her to answer; so dorothy said, with hesitation, "you are very kind, but there must be some mistake.',
#  u'i have not killed anything."',
#  u'"your house did, anyway," replied the little old woman, with a laugh, "and that is the same thing.',
#  u'see!"',
#  u'she continued, pointing to the corner of the house.',
#  u'"there are her two feet, still sticking out from under a block of wood."',
#  u'dorothy looked, and gave a little cry of fright.',
#  u'there, indeed, just under the corner of the great beam the house rested on, two feet were sticking out, shod in silver shoes with pointed toes.',
#  u'"oh, dear!',
#  u'oh, dear!"',
#  u'cried dorothy, clasping her hands together in dismay.',
#  u'"the house must have fallen on her.',
#  u'whatever shall we do?"',
#  u'"there is nothing to be done," said the little woman calmly.',
#  u'"but who was she?"',
#  u'asked dorothy.',
#  u'"she was the wicked witch of the east, as i said," answered the little woman.',
#  u'"she has held all the munchkins in bondage for many years, making them slave for her night and day.',
#  u'now they are all set free, and are grateful to you for the favor."',
#  u'"who are the munchkins?"',
#  u'inquired dorothy.',
#  u'"they are the people who live in this land of the east  where the wicked witch ruled."',
#  u'"are you a munchkin?"',
#  u'asked dorothy.',
#  u'"no, but i am their friend, although i live in the land of the north.',
#  u'when they saw the witch of the east was dead the munchkins sent a swift messenger to me, and i came at once.',
#  u'i am the witch of the north."',
#  u'"oh, gracious!"',
#  u'cried dorothy.',
#  u'"are you a real witch?"',
#  u'"yes, indeed," answered the little woman.',
#  u'"but i am a good witch, and the people love me.',
#  u'i am not as powerful as the wicked witch was who ruled here, or i should have set the people free myself."',
#  u'"but i thought all witches were wicked," said the girl, who was half frightened at facing a real witch.',
#  u'"oh, no, that is a great mistake.',
#  u'there were only four witches in all the land of oz, and two of them, those who live in the north and the south, are good witches.',
#  u'i know this is true, for i am one of them myself, and cannot be mistaken.',
#  u'those who dwelt in the east and the west were, indeed, wicked witches; but now that you have killed one of them, there is but one wicked witch in all the land of oz--the one who lives in the west."',
#  u'"but," said dorothy, after a moment\'s thought, "aunt em has told me that the witches were all dead--years and years ago."',
#  u'"who is aunt em?"',
#  u'inquired the little old woman.',
#  u'"she is my aunt who lives in kansas, where i came from."',
#  u'the witch of the north seemed to think for a time, with her head bowed and her eyes upon the ground.',
#  u'then she looked up and said, "i do not know where kansas is, for i have never heard that country mentioned before.',
#  u'but tell me, is it a civilized country?"',
#  u'"oh, yes," replied dorothy.',
#  u'"then that accounts for it.',
#  u'in the civilized countries i believe there are no witches left, nor wizards, nor sorceresses, nor magicians.',
#  u'but, you see, the land of oz has never been civilized, for we are cut off from all the rest of the world.',
#  u'therefore we still have witches and wizards amongst us."',
#  u'"who are the wizards?"',
#  u'asked dorothy.',
#  u'"oz himself is the great wizard," answered the witch, sinking her voice to a whisper.',
#  u'"he is more powerful than all the rest of us together.',
#  u'he lives in the city of emeralds."',
#  u'dorothy was going to ask another question, but just then the munchkins, who had been standing silently by, gave a loud shout and pointed to the corner of the house where the wicked witch had been lying.',
#  u'"what is it?"',
#  u'asked the little old woman, and looked, and began to laugh.',
#  u'the feet of the dead witch had disappeared entirely, and nothing was left but the silver shoes.',
#  u'"she was so old," explained the witch of the north, "that she dried up quickly in the sun.',
#  u'that is the end of her.',
#  u'but the silver shoes are yours, and you shall have them to wear."',
#  u'she reached down and picked up the shoes, and after shaking the dust out of them handed them to dorothy.',
#  u'"the witch of the east was proud of those silver shoes," said one of the munchkins, "and there is some charm connected with them; but what it is we never knew."',
#  u'dorothy carried the shoes into the house and placed them on the table.',
#  u'then she came out again to the munchkins and said:  "i am anxious to get back to my aunt and uncle, for i am sure they will worry about me.',
#  u'can you help me find my way?"',
#  u'the munchkins and the witch first looked at one another, and then at dorothy, and then shook their heads.',
#  u'"at the east, not far from here," said one, "there is a great desert, and none could live to cross it."',
#  u'"it is the same at the south," said another, "for i have been there and seen it.',
#  u'the south is the country of the quadlings."',
#  u'"i am told," said the third man, "that it is the same at the west.',
#  u'and that country, where the winkies live, is ruled by the wicked witch of the west, who would make you her slave if you passed her way."',
#  u'"the north is my home," said the old lady, "and at its edge is the same great desert that surrounds this land of oz.',
#  u'i\'m afraid, my dear, you will have to live with us."',
#  u'dorothy began to sob at this, for she felt lonely among all these strange people.',
#  u'her tears seemed to grieve the kind-hearted munchkins, for they immediately took out their handkerchiefs and began to weep also.',
#  u'as for the little old woman, she took off her cap and balanced the point on the end of her nose, while she counted "one, two, three" in a solemn voice.',
#  u'at once the cap changed to a slate, on which was written in big, white chalk marks:    "let dorothy go to the city of emeralds"   the little old woman took the slate from her nose, and having read the words on it, asked, "is your name dorothy, my dear?"',
#  u'"yes," answered the child, looking up and drying her tears.',
#  u'"then you must go to the city of emeralds.',
#  u'perhaps oz will help you."',
#  u'"where is this city?"',
#  u'asked dorothy.',
#  u'"it is exactly in the center of the country, and is ruled by oz, the great wizard i told you of."',
#  u'"is he a good man?"',
#  u'inquired the girl anxiously.',
#  u'"he is a good wizard.',
#  u'whether he is a man or not i cannot tell, for i have never seen him."',
#  u'"how can i get there?"',
#  u'asked dorothy.',
#  u'"you must walk.',
#  u'it is a long journey, through a country that is sometimes pleasant and sometimes dark and terrible.',
#  u'however, i will use all the magic arts i know of to keep you from harm."',
#  u'"won\'t you go with me?"',
#  u'pleaded the girl, who had begun to look upon the little old woman as her only friend.',
#  u'"no, i cannot do that," she replied, "but i will give you my kiss, and no one will dare injure a person who has been kissed by the witch of the north."',
#  u'she came close to dorothy and kissed her gently on the forehead.',
#  u'where her lips touched the girl they left a round, shining mark, as dorothy found out soon after.',
#  u'"the road to the city of emeralds is paved with yellow brick," said the witch, "so you cannot miss it.',
#  u'when you get to oz do not be afraid of him, but tell your story and ask him to help you.',
#  u'good-bye, my dear."',
#  u'the three munchkins bowed low to her and wished her a pleasant journey, after which they walked away through the trees.',
#  u'the witch gave dorothy a friendly little nod, whirled around on her left heel three times, and straightway disappeared, much to the surprise of little toto, who barked after her loudly enough when she had gone, because he had been afraid even to growl while she stood by.',
#  u'but dorothy, knowing her to be a witch, had expected her to disappear in just that way, and was not surprised in the least.',
#  u'3.  how dorothy saved the scarecrow   when dorothy was left alone she began to feel hungry.',
#  u'so she went to the cupboard and cut herself some bread, which she spread with butter.',
#  u'she gave some to toto, and taking a pail from the shelf she carried it down to the little brook and filled it with clear, sparkling water.',
#  u'toto ran over to the trees and began to bark at the birds sitting there.',
#  u'dorothy went to get him, and saw such delicious fruit hanging from the branches that she gathered some of it, finding it just what she wanted to help out her breakfast.',
#  u'then she went back to the house, and having helped herself and toto to a good drink of the cool, clear water, she set about making ready for the journey to the city of emeralds.',
#  u'dorothy had only one other dress, but that happened to be clean and was hanging on a peg beside her bed.',
#  u'it was gingham, with checks of white and blue; and although the blue was somewhat faded with many washings, it was still a pretty frock.',
#  u'the girl washed herself carefully, dressed herself in the clean gingham, and tied her pink sunbonnet on her head.',
#  u'she took a little basket and filled it with bread from the cupboard, laying a white cloth over the top.',
#  u'then she looked down at her feet and noticed how old and worn her shoes were.',
#  u'"they surely will never do for a long journey, toto," she said.',
#  u'and toto looked up into her face with his little black eyes and wagged his tail to show he knew what she meant.',
#  u'at that moment dorothy saw lying on the table the silver shoes that had belonged to the witch of the east.',
#  u'"i wonder if they will fit me," she said to toto.',
#  u'"they would be just the thing to take a long walk in, for they could not wear out."',
#  u'she took off her old leather shoes and tried on the silver ones, which fitted her as well as if they had been made for her.',
#  u'finally she picked up her basket.',
#  u'"come along, toto," she said.',
#  u'"we will go to the emerald city and ask the great oz how to get back to kansas again."',
#  u'she closed the door, locked it, and put the key carefully in the pocket of her dress.',
#  u'and so, with toto trotting along soberly behind her, she started on her journey.',
#  u'there were several roads nearby, but it did not take her long to find the one paved with yellow bricks.',
#  u'within a short time she was walking briskly toward the emerald city, her silver shoes tinkling merrily on the hard, yellow road-bed.',
#  u'the sun shone bright and the birds sang sweetly, and dorothy did not feel nearly so bad as you might think a little girl would who had been suddenly whisked away from her own country and set down in the midst of a strange land.',
#  u'she was surprised, as she walked along, to see how pretty the country was about her.',
#  u'there were neat fences at the sides of the road, painted a dainty blue color, and beyond them were fields of grain and vegetables in abundance.',
#  u'evidently the munchkins were good farmers and able to raise large crops.',
#  u'once in a while she would pass a house, and the people came out to look at her and bow low as she went by; for everyone knew she had been the means of destroying the wicked witch and setting them free from bondage.',
#  u'the houses of the munchkins were odd-looking dwellings, for each was round, with a big dome for a roof.',
#  u'all were painted blue, for in this country of the east blue was the favorite color.',
#  u'toward evening, when dorothy was tired with her long walk and began to wonder where she should pass the night, she came to a house rather larger than the rest.',
#  u'on the green lawn before it many men and women were dancing.',
#  u'five little fiddlers played as loudly as possible, and the people were laughing and singing, while a big table near by was loaded with delicious fruits and nuts, pies and cakes, and many other good things to eat.',
#  u'the people greeted dorothy kindly, and invited her to supper and to pass the night with them; for this was the home of one of the richest munchkins in the land, and his friends were gathered with him to celebrate their freedom from the bondage of the wicked witch.',
#  u'dorothy ate a hearty supper and was waited upon by the rich munchkin himself, whose name was boq.',
#  u'then she sat upon a settee and watched the people dance.',
#  u'when boq saw her silver shoes he said, "you must be a great sorceress."',
#  u'"why?"',
#  u'asked the girl.',
#  u'"because you wear silver shoes and have killed the wicked witch.',
#  u'besides, you have white in your frock, and only witches and sorceresses wear white."',
#  u'"my dress is blue and white checked," said dorothy, smoothing out the wrinkles in it.',
#  u'"it is kind of you to wear that," said boq.',
#  u'"blue is the color of the munchkins, and white is the witch color.',
#  u'so we know you are a friendly witch."',
#  u'dorothy did not know what to say to this, for all the people seemed to think her a witch, and she knew very well she was only an ordinary little girl who had come by the chance of a cyclone into a strange land.',
#  u'when she had tired watching the dancing, boq led her into the house, where he gave her a room with a pretty bed in it.',
#  u'the sheets were made of blue cloth, and dorothy slept soundly in them till morning, with toto curled up on the blue rug beside her.',
#  u'she ate a hearty breakfast, and watched a wee munchkin baby, who played with toto and pulled his tail and crowed and laughed in a way that greatly amused dorothy.',
#  u'toto was a fine curiosity to all the people, for they had never seen a dog before.',
#  u'"how far is it to the emerald city?"',
#  u'the girl asked.',
#  u'"i do not know," answered boq gravely, "for i have never been there.',
#  u'it is better for people to keep away from oz, unless they have business with him.',
#  u'but it is a long way to the emerald city, and it will take you many days.',
#  u'the country here is rich and pleasant, but you must pass through rough and dangerous places before you reach the end of your journey."',
#  u'this worried dorothy a little, but she knew that only the great oz could help her get to kansas again, so she bravely resolved not to turn back.',
#  u'she bade her friends good-bye, and again started along the road of yellow brick.',
#  u'when she had gone several miles she thought she would stop to rest, and so climbed to the top of the fence beside the road and sat down.',
#  u'there was a great cornfield beyond the fence, and not far away she saw a scarecrow, placed high on a pole to keep the birds from the ripe corn.',
#  u'dorothy leaned her chin upon her hand and gazed thoughtfully at the scarecrow.',
#  u'its head was a small sack stuffed with straw, with eyes, nose, and mouth painted on it to represent a face.',
#  u'an old, pointed blue hat, that had belonged to some munchkin, was perched on his head, and the rest of the figure was a blue suit of clothes, worn and faded, which had also been stuffed with straw.',
#  u'on the feet were some old boots with blue tops, such as every man wore in this country, and the figure was raised above the stalks of corn by means of the pole stuck up its back.',
#  u'while dorothy was looking earnestly into the queer, painted face of the scarecrow, she was surprised to see one of the eyes slowly wink at her.',
#  u'she thought she must have been mistaken at first, for none of the scarecrows in kansas ever wink; but presently the figure nodded its head to her in a friendly way.',
#  u'then she climbed down from the fence and walked up to it, while toto ran around the pole and barked.',
#  u'"good day," said the scarecrow, in a rather husky voice.',
#  u'"did you speak?"',
#  u'asked the girl, in wonder.',
#  u'"certainly," answered the scarecrow.',
#  u'"how do you do?"',
#  u'"i\'m pretty well, thank you," replied dorothy politely.',
#  u'"how do you do?"',
#  u'"i\'m not feeling well," said the scarecrow, with a smile, "for it is very tedious being perched up here night and day to scare away crows."',
#  u'"can\'t you get down?"',
#  u'asked dorothy.',
#  u'"no, for this pole is stuck up my back.',
#  u'if you will please take away the pole i shall be greatly obliged to you."',
#  u'dorothy reached up both arms and lifted the figure off the pole, for, being stuffed with straw, it was quite light.',
#  u'"thank you very much," said the scarecrow, when he had been set down on the ground.',
#  u'"i feel like a new man."',
#  u'dorothy was puzzled at this, for it sounded queer to hear a stuffed man speak, and to see him bow and walk along beside her.',
#  u'"who are you?"',
#  u'asked the scarecrow when he had stretched himself and yawned.',
#  u'"and where are you going?"',
#  u'"my name is dorothy," said the girl, "and i am going to the emerald city, to ask the great oz to send me back to kansas."',
#  u'"where is the emerald city?"',
#  u'he inquired.',
#  u'"and who is oz?"',
#  u'"why, don\'t you know?"',
#  u'she returned, in surprise.',
#  u'"no, indeed.',
#  u"i don't know anything.",
#  u'you see, i am stuffed, so i have no brains at all," he answered sadly.',
#  u'"oh," said dorothy, "i\'m awfully sorry for you."',
#  u'"do you think," he asked, "if i go to the emerald city with you, that oz would give me some brains?"',
#  u'"i cannot tell," she returned, "but you may come with me, if you like.',
#  u'if oz will not give you any brains you will be no worse off than you are now."',
#  u'"that is true," said the scarecrow.',
#  u'"you see," he continued confidentially, "i don\'t mind my legs and arms and body being stuffed, because i cannot get hurt.',
#  u"if anyone treads on my toes or sticks a pin into me, it doesn't matter, for i can't feel it.",
#  u'but i do not want people to call me a fool, and if my head stays stuffed with straw instead of with brains, as yours is, how am i ever to know anything?"',
#  u'"i understand how you feel," said the little girl, who was truly sorry for him.',
#  u'"if you will come with me i\'ll ask oz to do all he can for you."',
#  u'"thank you," he answered gratefully.',
#  u'they walked back to the road.',
#  u'dorothy helped him over the fence, and they started along the path of yellow brick for the emerald city.',
#  u'toto did not like this addition to the party at first.',
#  u'he smelled around the stuffed man as if he suspected there might be a nest of rats in the straw, and he often growled in an unfriendly way at the scarecrow.',
#  u'"don\'t mind toto," said dorothy to her new friend.',
#  u'"he never bites."',
#  u'"oh, i\'m not afraid," replied the scarecrow.',
#  u'"he can\'t hurt the straw.',
#  u'do let me carry that basket for you.',
#  u"i shall not mind it, for i can't get tired.",
#  u'i\'ll tell you a secret," he continued, as he walked along.',
#  u'"there is only one thing in the world i am afraid of."',
#  u'"what is that?"',
#  u'asked dorothy; "the munchkin farmer who made you?"',
#  u'"no," answered the scarecrow; "it\'s a lighted match."',
#  u'4.  the road through the forest   after a few hours the road began to be rough, and the walking grew so difficult that the scarecrow often stumbled over the yellow bricks, which were here very uneven.',
#  u'sometimes, indeed, they were broken or missing altogether, leaving holes that toto jumped across and dorothy walked around.',
#  u'as for the scarecrow, having no brains, he walked straight ahead, and so stepped into the holes and fell at full length on the hard bricks.',
#  u'it never hurt him, however, and dorothy would pick him up and set him upon his feet again, while he joined her in laughing merrily at his own mishap.',
#  u'the farms were not nearly so well cared for here as they were farther back.',
#  u'there were fewer houses and fewer fruit trees, and the farther they went the more dismal and lonesome the country became.',
#  u'at noon they sat down by the roadside, near a little brook, and dorothy opened her basket and got out some bread.',
#  u'she offered a piece to the scarecrow, but he refused.',
#  u'"i am never hungry," he said, "and it is a lucky thing i am not, for my mouth is only painted, and if i should cut a hole in it so i could eat, the straw i am stuffed with would come out, and that would spoil the shape of my head."',
#  u'dorothy saw at once that this was true, so she only nodded and went on eating her bread.',
#  u'"tell me something about yourself and the country you came from," said the scarecrow, when she had finished her dinner.',
#  u'so she told him all about kansas, and how gray everything was there, and how the cyclone had carried her to this queer land of oz.',
#  u'the scarecrow listened carefully, and said, "i cannot understand why you should wish to leave this beautiful country and go back to the dry, gray place you call kansas."',
#  u'"that is because you have no brains" answered the girl.',
#  u'"no matter how dreary and gray our homes are, we people of flesh and blood would rather live there than in any other country, be it ever so beautiful.',
#  u'there is no place like home."',
#  u'the scarecrow sighed.',
#  u'"of course i cannot understand it," he said.',
#  u'"if your heads were stuffed with straw, like mine, you would probably all live in the beautiful places, and then kansas would have no people at all.',
#  u'it is fortunate for kansas that you have brains."',
#  u'"won\'t you tell me a story, while we are resting?"',
#  u'asked the child.',
#  u'the scarecrow looked at her reproachfully, and answered:  "my life has been so short that i really know nothing whatever.',
#  u'i was only made day before yesterday.',
#  u'what happened in the world before that time is all unknown to me.',
#  u'luckily, when the farmer made my head, one of the first things he did was to paint my ears, so that i heard what was going on.',
#  u"there was another munchkin with him, and the first thing i heard was the farmer saying, 'how do you like those ears?'",
#  u'"\'they aren\'t straight,\'" answered the other.',
#  u'"\'never mind,\'" said the farmer.',
#  u'"\'they are ears just the same,\'" which was true enough.',
#  u'"\'now i\'ll make the eyes,\'" said the farmer.',
#  u'so he painted my right eye, and as soon as it was finished i found myself looking at him and at everything around me with a great deal of curiosity, for this was my first glimpse of the world.',
#  u'"\'that\'s a rather pretty eye,\'" remarked the munchkin who was watching the farmer.',
#  u'"\'blue paint is just the color for eyes.\'',
#  u'"\'i think i\'ll make the other a little bigger,\'" said the farmer.',
#  u'and when the second eye was done i could see much better than before.',
#  u'then he made my nose and my mouth.',
#  u"but i did not speak, because at that time i didn't know what a mouth was for.",
#  u'i had the fun of watching them make my body and my arms and legs; and when they fastened on my head, at last, i felt very proud, for i thought i was just as good a man as anyone.',
#  u'"\'this fellow will scare the crows fast enough,\' said the farmer.',
#  u"'he looks just like a man.'",
#  u'"\'why, he is a man,\' said the other, and i quite agreed with him.',
#  u'the farmer carried me under his arm to the cornfield, and set me up on a tall stick, where you found me.',
#  u'he and his friend soon after walked away and left me alone.',
#  u'"i did not like to be deserted this way.',
#  u'so i tried to walk after them.',
#  u'but my feet would not touch the ground, and i was forced to stay on that pole.',
#  u'it was a lonely life to lead, for i had nothing to think of, having been made such a little while before.',
#  u'many crows and other birds flew into the cornfield, but as soon as they saw me they flew away again, thinking i was a munchkin; and this pleased me and made me feel that i was quite an important person.',
#  u'by and by an old crow flew near me, and after looking at me carefully he perched upon my shoulder and said:  "\'i wonder if that farmer thought to fool me in this clumsy manner.',
#  u"any crow of sense could see that you are only stuffed with straw.'",
#  u'then he hopped down at my feet and ate all the corn he wanted.',
#  u'the other birds, seeing he was not harmed by me, came to eat the corn too, so in a short time there was a great flock of them about me.',
#  u'"i felt sad at this, for it showed i was not such a good scarecrow after all; but the old crow comforted me, saying, \'if you only had brains in your head you would be as good a man as any of them, and a better man than some of them.',
#  u"brains are the only things worth having in this world, no matter whether one is a crow or a man.'",
#  u'"after the crows had gone i thought this over, and decided i would try hard to get some brains.',
#  u'by good luck you came along and pulled me off the stake, and from what you say i am sure the great oz will give me brains as soon as we get to the emerald city."',
#  u'"i hope so," said dorothy earnestly, "since you seem anxious to have them."',
#  u'"oh, yes; i am anxious," returned the scarecrow.',
#  u'"it is such an uncomfortable feeling to know one is a fool."',
#  u'"well," said the girl, "let us go."',
#  u'and she handed the basket to the scarecrow.',
#  u'there were no fences at all by the roadside now, and the land was rough and untilled.',
#  u'toward evening they came to a great forest, where the trees grew so big and close together that their branches met over the road of yellow brick.',
#  u'it was almost dark under the trees, for the branches shut out the daylight; but the travelers did not stop, and went on into the forest.',
#  u'"if this road goes in, it must come out," said the scarecrow, "and as the emerald city is at the other end of the road, we must go wherever it leads us."',
#  u'"anyone would know that," said dorothy.',
#  u'"certainly; that is why i know it," returned the scarecrow.',
#  u'"if it required brains to figure it out, i never should have said it."',
#  u'after an hour or so the light faded away, and they found themselves stumbling along in the darkness.',
#  u'dorothy could not see at all, but toto could, for some dogs see very well in the dark; and the scarecrow declared he could see as well as by day.',
#  u'so she took hold of his arm and managed to get along fairly well.',
#  u'"if you see any house, or any place where we can pass the night," she said, "you must tell me; for it is very uncomfortable walking in the dark."',
#  u'soon after the scarecrow stopped.',
#  u'"i see a little cottage at the right of us," he said, "built of logs and branches.',
#  u'shall we go there?"',
#  u'"yes, indeed," answered the child.',
#  u'"i am all tired out."',
#  u'so the scarecrow led her through the trees until they reached the cottage, and dorothy entered and found a bed of dried leaves in one corner.',
#  u'she lay down at once, and with toto beside her soon fell into a sound sleep.',
#  u'the scarecrow, who was never tired, stood up in another corner and waited patiently until morning came.',
#  u'5.  the rescue of the tin woodman   when dorothy awoke the sun was shining through the trees and toto had long been out chasing birds around him and squirrels.',
#  u'she sat up and looked around her.',
#  u'there was the scarecrow, still standing patiently in his corner, waiting for her.',
#  u'"we must go and search for water," she said to him.',
#  u'"why do you want water?"',
#  u'he asked.',
#  u'"to wash my face clean after the dust of the road, and to drink, so the dry bread will not stick in my throat."',
#  u'"it must be inconvenient to be made of flesh," said the scarecrow thoughtfully, "for you must sleep, and eat and drink.',
#  u'however, you have brains, and it is worth a lot of bother to be able to think properly."',
#  u'they left the cottage and walked through the trees until they found a little spring of clear water, where dorothy drank and bathed and ate her breakfast.',
#  u'she saw there was not much bread left in the basket, and the girl was thankful the scarecrow did not have to eat anything, for there was scarcely enough for herself and toto for the day.',
#  u'when she had finished her meal, and was about to go back to the road of yellow brick, she was startled to hear a deep groan near by.',
#  u'"what was that?"',
#  u'she asked timidly.',
#  u'"i cannot imagine," replied the scarecrow; "but we can go and see."',
#  u'just then another groan reached their ears, and the sound seemed to come from behind them.',
#  u'they turned and walked through the forest a few steps, when dorothy discovered something shining in a ray of sunshine that fell between the trees.',
#  u'she ran to the place and then stopped short, with a little cry of surprise.',
#  u'one of the big trees had been partly chopped through, and standing beside it, with an uplifted axe in his hands, was a man made entirely of tin.',
#  u'his head and arms and legs were jointed upon his body, but he stood perfectly motionless, as if he could not stir at all.',
#  u'dorothy looked at him in amazement, and so did the scarecrow, while toto barked sharply and made a snap at the tin legs, which hurt his teeth.',
#  u'"did you groan?"',
#  u'asked dorothy.',
#  u'"yes," answered the tin man, "i did.',
#  u'i\'ve been groaning for more than a year, and no one has ever heard me before or come to help me."',
#  u'"what can i do for you?"',
#  u'she inquired softly, for she was moved by the sad voice in which the man spoke.',
#  u'"get an oil-can and oil my joints," he answered.',
#  u'"they are rusted so badly that i cannot move them at all; if i am well oiled i shall soon be all right again.',
#  u'you will find an oil-can on a shelf in my cottage."',
#  u'dorothy at once ran back to the cottage and found the oil-can, and then she returned and asked anxiously, "where are your joints?"',
#  u'"oil my neck, first," replied the tin woodman.',
#  u'so she oiled it, and as it was quite badly rusted the scarecrow took hold of the tin head and moved it gently from side to side until it worked freely, and then the man could turn it himself.',
#  u'"now oil the joints in my arms," he said.',
#  u'and dorothy oiled them and the scarecrow bent them carefully until they were quite free from rust and as good as new.',
#  u'the tin woodman gave a sigh of satisfaction and lowered his axe, which he leaned against the tree.',
#  u'"this is a great comfort," he said.',
#  u'"i have been holding that axe in the air ever since i rusted, and i\'m glad to be able to put it down at last.',
#  u'now, if you will oil the joints of my legs, i shall be all right once more."',
#  u'so they oiled his legs until he could move them freely; and he thanked them again and again for his release, for he seemed a very polite creature, and very grateful.',
#  u'"i might have stood there always if you had not come along," he said; "so you have certainly saved my life.',
#  u'how did you happen to be here?"',
#  u'"we are on our way to the emerald city to see the great oz," she answered, "and we stopped at your cottage to pass the night."',
#  u'"why do you wish to see oz?"',
#  u'he asked.',
#  u'"i want him to send me back to kansas, and the scarecrow wants him to put a few brains into his head," she replied.',
#  u'the tin woodman appeared to think deeply for a moment.',
#  u'then he said:  "do you suppose oz could give me a heart?"',
#  u'"why, i guess so," dorothy answered.',
#  u'"it would be as easy as to give the scarecrow brains."',
#  u'"true," the tin woodman returned.',
#  u'"so, if you will allow me to join your party, i will also go to the emerald city and ask oz to help me."',
#  u'"come along," said the scarecrow heartily, and dorothy added that she would be pleased to have his company.',
#  u'so the tin woodman shouldered his axe and they all passed through the forest until they came to the road that was paved with yellow brick.',
#  u'the tin woodman had asked dorothy to put the oil-can in her basket.',
#  u'"for," he said, "if i should get caught in the rain, and rust again, i would need the oil-can badly."',
#  u'it was a bit of good luck to have their new comrade join the party, for soon after they had begun their journey again they came to a place where the trees and branches grew so thick over the road that the travelers could not pass.',
#  u'but the tin woodman set to work with his axe and chopped so well that soon he cleared a passage for the entire party.',
#  u'dorothy was thinking so earnestly as they walked along that she did not notice when the scarecrow stumbled into a hole and rolled over to the side of the road.',
#  u'indeed he was obliged to call to her to help him up again.',
#  u'"why didn\'t you walk around the hole?"',
#  u'asked the tin woodman.',
#  u'"i don\'t know enough," replied the scarecrow cheerfully.',
#  u'"my head is stuffed with straw, you know, and that is why i am going to oz to ask him for some brains."',
#  u'"oh, i see," said the tin woodman.',
#  u'"but, after all, brains are not the best things in the world."',
#  u'"have you any?"',
#  u'inquired the scarecrow.',
#  u'"no, my head is quite empty," answered the woodman.',
#  u'"but once i had brains, and a heart also; so, having tried them both, i should much rather have a heart."',
#  u'"and why is that?"',
#  u'asked the scarecrow.',
#  u'"i will tell you my story, and then you will know."',
#  u'so, while they were walking through the forest, the tin woodman told the following story:  "i was born the son of a woodman who chopped down trees in the forest and sold the wood for a living.',
#  u'when i grew up, i too became a woodchopper, and after my father died i took care of my old mother as long as she lived.',
#  u'then i made up my mind that instead of living alone i would marry, so that i might not become lonely.',
#  u'"there was one of the munchkin girls who was so beautiful that i soon grew to love her with all my heart.',
#  u'she, on her part, promised to marry me as soon as i could earn enough money to build a better house for her; so i set to work harder than ever.',
#  u'but the girl lived with an old woman who did not want her to marry anyone, for she was so lazy she wished the girl to remain with her and do the cooking and the housework.',
#  u'so the old woman went to the wicked witch of the east, and promised her two sheep and a cow if she would prevent the marriage.',
#  u'thereupon the wicked witch enchanted my axe, and when i was chopping away at my best one day, for i was anxious to get the new house and my wife as soon as possible, the axe slipped all at once and cut off my left leg.',
#  u'"this at first seemed a great misfortune, for i knew a one-legged man could not do very well as a wood-chopper.',
#  u'so i went to a tinsmith and had him make me a new leg out of tin.',
#  u'the leg worked very well, once i was used to it.',
#  u'but my action angered the wicked witch of the east, for she had promised the old woman i should not marry the pretty munchkin girl.',
#  u'when i began chopping again, my axe slipped and cut off my right leg.',
#  u'again i went to the tinsmith, and again he made me a leg out of tin.',
#  u'after this the enchanted axe cut off my arms, one after the other; but, nothing daunted, i had them replaced with tin ones.',
#  u'the wicked witch then made the axe slip and cut off my head, and at first i thought that was the end of me.',
#  u'but the tinsmith happened to come along, and he made me a new head out of tin.',
#  u'"i thought i had beaten the wicked witch then, and i worked harder than ever; but i little knew how cruel my enemy could be.',
#  u'she thought of a new way to kill my love for the beautiful munchkin maiden, and made my axe slip again, so that it cut right through my body, splitting me into two halves.',
#  u'once more the tinsmith came to my help and made me a body of tin, fastening my tin arms and legs and head to it, by means of joints, so that i could move around as well as ever.',
#  u'but, alas!',
#  u'i had now no heart, so that i lost all my love for the munchkin girl, and did not care whether i married her or not.',
#  u'i suppose she is still living with the old woman, waiting for me to come after her.',
#  u'"my body shone so brightly in the sun that i felt very proud of it and it did not matter now if my axe slipped, for it could not cut me.',
#  u'there was only one danger--that my joints would rust; but i kept an oil-can in my cottage and took care to oil myself whenever i needed it.',
#  u'however, there came a day when i forgot to do this, and, being caught in a rainstorm, before i thought of the danger my joints had rusted, and i was left to stand in the woods until you came to help me.',
#  u'it was a terrible thing to undergo, but during the year i stood there i had time to think that the greatest loss i had known was the loss of my heart.',
#  u'while i was in love i was the happiest man on earth; but no one can love who has not a heart, and so i am resolved to ask oz to give me one.',
#  u'if he does, i will go back to the munchkin maiden and marry her."',
#  u'both dorothy and the scarecrow had been greatly interested in the story of the tin woodman, and now they knew why he was so anxious to get a new heart.',
#  u'"all the same," said the scarecrow, "i shall ask for brains instead of a heart; for a fool would not know what to do with a heart if he had one."',
#  u'"i shall take the heart," returned the tin woodman; "for brains do not make one happy, and happiness is the best thing in the world."',
# ...
#  u'it was about this time that dorothy woke from her long sleep and opened her eyes.',
#  u'she was greatly astonished to find herself lying upon the grass, with thousands of mice standing around and looking at her timidly.',
#  u'but the scarecrow told her about everything, and turning to the dignified little mouse, he said:  "permit me to introduce to you her majesty, the queen."',
#  u'dorothy nodded gravely and the queen made a curtsy, after which she became quite friendly with the little girl.',
#  u'the scarecrow and the woodman now began to fasten the mice to the truck, using the strings they had brought.',
#  u'one end of a string was tied around the neck of each mouse and the other end to the truck.',
#  u'of course the truck was a thousand times bigger than any of the mice who were to draw it; but when all the mice had been harnessed, they were able to pull it quite easily.',
#  u'even the scarecrow and the tin woodman could sit on it, and were drawn swiftly by their queer little horses to the place where the lion lay asleep.',
#  u'after a great deal of hard work, for the lion was heavy, they managed to get him up on the truck.',
#  u'then the queen hurriedly gave her people the order to start, for she feared if the mice stayed among the poppies too long they also would fall asleep.',
#  u'at first the little creatures, many though they were, could hardly stir the heavily loaded truck; but the woodman and the scarecrow both pushed from behind, and they got along better.',
#  u'soon they rolled the lion out of the poppy bed to the green fields, where he could breathe the sweet, fresh air again, instead of the poisonous scent of the flowers.',
#  u'dorothy came to meet them and thanked the little mice warmly for saving her companion from death.',
#  u'she had grown so fond of the big lion she was glad he had been rescued.',
#  u'then the mice were unharnessed from the truck and scampered away through the grass to their homes.',
#  u'the queen of the mice was the last to leave.',
#  u'"if ever you need us again," she said, "come out into the field and call, and we shall hear you and come to your assistance.',
#  u'good-bye!"',
#  u'"good-bye!"',
#  u'they all answered, and away the queen ran, while dorothy held toto tightly lest he should run after her and frighten her.',
#  u'after this they sat down beside the lion until he should awaken; and the scarecrow brought dorothy some fruit from a tree near by, which she ate for her dinner.',
#  u'10.  the guardian of the gate   it was some time before the cowardly lion awakened, for he had lain among the poppies a long while, breathing in their deadly fragrance; but when he did open his eyes and roll off the truck he was very glad to find himself still alive.',
#  u'"i ran as fast as i could," he said, sitting down and yawning, "but the flowers were too strong for me.',
#  u'how did you get me out?"',
#  u'then they told him of the field mice, and how they had generously saved him from death; and the cowardly lion laughed, and said:  "i have always thought myself very big and terrible; yet such little things as flowers came near to killing me, and such small animals as mice have saved my life.',
#  u'how strange it all is!',
#  u'but, comrades, what shall we do now?"',
#  u'"we must journey on until we find the road of yellow brick again," said dorothy, "and then we can keep on to the emerald city."',
#  u'so, the lion being fully refreshed, and feeling quite himself again, they all started upon the journey, greatly enjoying the walk through the soft, fresh grass; and it was not long before they reached the road of yellow brick and turned again toward the emerald city where the great oz dwelt.',
#  u'the road was smooth and well paved, now, and the country about was beautiful, so that the travelers rejoiced in leaving the forest far behind, and with it the many dangers they had met in its gloomy shades.',
#  u'once more they could see fences built beside the road; but these were painted green, and when they came to a small house, in which a farmer evidently lived, that also was painted green.',
#  u'they passed by several of these houses during the afternoon, and sometimes people came to the doors and looked at them as if they would like to ask questions; but no one came near them nor spoke to them because of the great lion, of which they were very much afraid.',
#  u'the people were all dressed in clothing of a lovely emerald-green color and wore peaked hats like those of the munchkins.',
#  u'"this must be the land of oz," said dorothy, "and we are surely getting near the emerald city."',
#  u'"yes," answered the scarecrow.',
#  u'"everything is green here, while in the country of the munchkins blue was the favorite color.',
#  u'but the people do not seem to be as friendly as the munchkins, and i\'m afraid we shall be unable to find a place to pass the night."',
#  u'"i should like something to eat besides fruit," said the girl, "and i\'m sure toto is nearly starved.',
#  u'let us stop at the next house and talk to the people."',
#  u'so, when they came to a good-sized farmhouse, dorothy walked boldly up to the door and knocked.',
#  u'a woman opened it just far enough to look out, and said, "what do you want, child, and why is that great lion with you?"',
#  u'"we wish to pass the night with you, if you will allow us," answered dorothy; "and the lion is my friend and comrade, and would not hurt you for the world."',
#  u'"is he tame?"',
#  u'asked the woman, opening the door a little wider.',
#  u'"oh, yes," said the girl, "and he is a great coward, too.',
#  u'he will be more afraid of you than you are of him."',
#  u'"well," said the woman, after thinking it over and taking another peep at the lion, "if that is the case you may come in, and i will give you some supper and a place to sleep."',
#  u'so they all entered the house, where there were, besides the woman, two children and a man.',
#  u'the man had hurt his leg, and was lying on the couch in a corner.',
#  u'they seemed greatly surprised to see so strange a company, and while the woman was busy laying the table the man asked:  "where are you all going?"',
#  u'"to the emerald city," said dorothy, "to see the great oz."',
#  u'"oh, indeed!"',
#  u'exclaimed the man.',
#  u'"are you sure that oz will see you?"',
#  u'"why not?"',
#  u'she replied.',
#  u'"why, it is said that he never lets anyone come into his presence.',
#  u'i have been to the emerald city many times, and it is a beautiful and wonderful place; but i have never been permitted to see the great oz, nor do i know of any living person who has seen him."',
#  u'"does he never go out?"',
#  u'asked the scarecrow.',
#  u'"never.',
#  u'he sits day after day in the great throne room of his palace, and even those who wait upon him do not see him face to face."',
#  u'"what is he like?"',
#  u'asked the girl.',
#  u'"that is hard to tell," said the man thoughtfully.',
#  u'"you see, oz is a great wizard, and can take on any form he wishes.',
#  u'so that some say he looks like a bird; and some say he looks like an elephant; and some say he looks like a cat.',
#  u'to others he appears as a beautiful fairy, or a brownie, or in any other form that pleases him.',
#  u'but who the real oz is, when he is in his own form, no living person can tell."',
#  u'"that is very strange," said dorothy, "but we must try, in some way, to see him, or we shall have made our journey for nothing."',
#  u'"why do you wish to see the terrible oz?"',
#  u'asked the man.',
#  u'"i want him to give me some brains," said the scarecrow eagerly.',
#  u'"oh, oz could do that easily enough," declared the man.',
#  u'"he has more brains than he needs."',
#  u'"and i want him to give me a heart," said the tin woodman.',
#  u'"that will not trouble him," continued the man, "for oz has a large collection of hearts, of all sizes and shapes."',
#  u'"and i want him to give me courage," said the cowardly lion.',
#  u'"oz keeps a great pot of courage in his throne room," said the man, "which he has covered with a golden plate, to keep it from running over.',
#  u'he will be glad to give you some."',
#  u'"and i want him to send me back to kansas," said dorothy.',
#  u'"where is kansas?"',
#  u'asked the man, with surprise.',
#  u'"i don\'t know," replied dorothy sorrowfully, "but it is my home, and i\'m sure it\'s somewhere."',
#  u'"very likely.',
#  u'well, oz can do anything; so i suppose he will find kansas for you.',
#  u'but first you must get to see him, and that will be a hard task; for the great wizard does not like to see anyone, and he usually has his own way.',
#  u'but what do you want?"',
#  u'he continued, speaking to toto.',
#  u'toto only wagged his tail; for, strange to say, he could not speak.',
#  u'the woman now called to them that supper was ready, so they gathered around the table and dorothy ate some delicious porridge and a dish of scrambled eggs and a plate of nice white bread, and enjoyed her meal.',
#  u'the lion ate some of the porridge, but did not care for it, saying it was made from oats and oats were food for horses, not for lions.',
#  u'the scarecrow and the tin woodman ate nothing at all.',
#  u'toto ate a little of everything, and was glad to get a good supper again.',
#  u'the woman now gave dorothy a bed to sleep in, and toto lay down beside her, while the lion guarded the door of her room so she might not be disturbed.',
#  u'the scarecrow and the tin woodman stood up in a corner and kept quiet all night, although of course they could not sleep.',
#  u'the next morning, as soon as the sun was up, they started on their way, and soon saw a beautiful green glow in the sky just before them.',
#  u'"that must be the emerald city," said dorothy.',
#  u'as they walked on, the green glow became brighter and brighter, and it seemed that at last they were nearing the end of their travels.',
#  u'yet it was afternoon before they came to the great wall that surrounded the city.',
#  u'it was high and thick and of a bright green color.',
#  u'in front of them, and at the end of the road of yellow brick, was a big gate, all studded with emeralds that glittered so in the sun that even the painted eyes of the scarecrow were dazzled by their brilliancy.',
#  u'there was a bell beside the gate, and dorothy pushed the button and heard a silvery tinkle sound within.',
#  u'then the big gate swung slowly open, and they all passed through and found themselves in a high arched room, the walls of which glistened with countless emeralds.',
#  u'before them stood a little man about the same size as the munchkins.',
#  u'he was clothed all in green, from his head to his feet, and even his skin was of a greenish tint.',
#  u'at his side was a large green box.',
#  u'when he saw dorothy and her companions the man asked, "what do you wish in the emerald city?"',
#  u'"we came here to see the great oz," said dorothy.',
#  u'the man was so surprised at this answer that he sat down to think it over.',
#  u'"it has been many years since anyone asked me to see oz," he said, shaking his head in perplexity.',
#  u'"he is powerful and terrible, and if you come on an idle or foolish errand to bother the wise reflections of the great wizard, he might be angry and destroy you all in an instant."',
#  u'"but it is not a foolish errand, nor an idle one," replied the scarecrow; "it is important.',
#  u'and we have been told that oz is a good wizard."',
#  u'"so he is," said the green man, "and he rules the emerald city wisely and well.',
#  u'but to those who are not honest, or who approach him from curiosity, he is most terrible, and few have ever dared ask to see his face.',
#  u'i am the guardian of the gates, and since you demand to see the great oz i must take you to his palace.',
#  u'but first you must put on the spectacles."',
#  u'"why?"',
#  u'asked dorothy.',
#  u'"because if you did not wear spectacles the brightness and glory of the emerald city would blind you.',
#  u'even those who live in the city must wear spectacles night and day.',
#  u'they are all locked on, for oz so ordered it when the city was first built, and i have the only key that will unlock them."',
#  u'he opened the big box, and dorothy saw that it was filled with spectacles of every size and shape.',
#  u'all of them had green glasses in them.',
#  u'the guardian of the gates found a pair that would just fit dorothy and put them over her eyes.',
#  u'there were two golden bands fastened to them that passed around the back of her head, where they were locked together by a little key that was at the end of a chain the guardian of the gates wore around his neck.',
#  u'when they were on, dorothy could not take them off had she wished, but of course she did not wish to be blinded by the glare of the emerald city, so she said nothing.',
#  u'then the green man fitted spectacles for the scarecrow and the tin woodman and the lion, and even on little toto; and all were locked fast with the key.',
#  u'then the guardian of the gates put on his own glasses and told them he was ready to show them to the palace.',
#  u'taking a big golden key from a peg on the wall, he opened another gate, and they all followed him through the portal into the streets of the emerald city.',
#  u'11.  the wonderful city of oz   even with eyes protected by the green spectacles, dorothy and her friends were at first dazzled by the brilliancy of the wonderful city.',
#  u'the streets were lined with beautiful houses all built of green marble and studded everywhere with sparkling emeralds.',
#  u'they walked over a pavement of the same green marble, and where the blocks were joined together were rows of emeralds, set closely, and glittering in the brightness of the sun.',
#  u'the window panes were of green glass; even the sky above the city had a green tint, and the rays of the sun were green.',
#  u'there were many people--men, women, and children--walking about, and these were all dressed in green clothes and had greenish skins.',
#  u'they looked at dorothy and her strangely assorted company with wondering eyes, and the children all ran away and hid behind their mothers when they saw the lion; but no one spoke to them.',
#  u'many shops stood in the street, and dorothy saw that everything in them was green.',
#  u'green candy and green pop corn were offered for sale, as well as green shoes, green hats, and green clothes of all sorts.',
#  u'at one place a man was selling green lemonade, and when the children bought it dorothy could see that they paid for it with green pennies.',
#  u'there seemed to be no horses nor animals of any kind; the men carried things around in little green carts, which they pushed before them.',
#  u'everyone seemed happy and contented and prosperous.',
#  u'the guardian of the gates led them through the streets until they came to a big building, exactly in the middle of the city, which was the palace of oz, the great wizard.',
#  u'there was a soldier before the door, dressed in a green uniform and wearing a long green beard.',
#  u'"here are strangers," said the guardian of the gates to him, "and they demand to see the great oz."',
#  u'"step inside," answered the soldier, "and i will carry your message to him."',
#  u'so they passed through the palace gates and were led into a big room with a green carpet and lovely green furniture set with emeralds.',
#  u'the soldier made them all wipe their feet upon a green mat before entering this room, and when they were seated he said politely:  "please make yourselves comfortable while i go to the door of the throne room and tell oz you are here."',
#  u'they had to wait a long time before the soldier returned.',
#  u'when, at last, he came back, dorothy asked:  "have you seen oz?"',
#  u'"oh, no," returned the soldier; "i have never seen him.',
#  u'but i spoke to him as he sat behind his screen and gave him your message.',
#  u'he said he will grant you an audience, if you so desire; but each one of you must enter his presence alone, and he will admit but one each day.',
#  u'therefore, as you must remain in the palace for several days, i will have you shown to rooms where you may rest in comfort after your journey."',
#  ...]

# %%
#Append SENTENCE_START and SENTENCE_END
sentences = ['%s %s %s' % (sentence_start_token, x, sentence_end_token) for x in sentences]

# %%
sentences
# Out:
# [u'SENTENCE_START introduction   folklore, legends, myths and fairy tales have followed childhood through the ages, for every healthy youngster has a wholesome and instinctive love for stories fantastic, marvelous and manifestly unreal. SENTENCE_END',
#  u'SENTENCE_START the winged fairies of grimm and andersen have brought more happiness to childish hearts than all other human creations. SENTENCE_END',
#  u'SENTENCE_START yet the old time fairy tale, having served for generations, may now be classed as "historical" in the children\'s library; for the time has come for a series of newer "wonder tales" in which the stereotyped genie, dwarf and fairy are eliminated, together with all the horrible and blood-curdling incidents devised by their authors to point a fearsome moral to each tale. SENTENCE_END',
#  u'SENTENCE_START modern education includes morality; therefore the modern child seeks only entertainment in its wonder tales and gladly dispenses with all disagreeable incident. SENTENCE_END',
#  u'SENTENCE_START having this thought in mind, the story of "the wonderful wizard of oz" was written solely to please children of today. SENTENCE_END',
#  u'SENTENCE_START it aspires to being a modernized fairy tale, in which the wonderment and joy are retained and the heartaches and nightmares are left out. SENTENCE_END',
#  u"SENTENCE_START l. frank baum  chicago, april, 1900.     the wonderful wizard of oz     1.  the cyclone   dorothy lived in the midst of the great kansas prairies, with uncle henry, who was a farmer, and aunt em, who was the farmer's wife. SENTENCE_END",
#  u'SENTENCE_START their house was small, for the lumber to build it had to be carried by wagon many miles. SENTENCE_END',
#  u'SENTENCE_START there were four walls, a floor and a roof, which made one room; and this room contained a rusty looking cookstove, a cupboard for the dishes, a table, three or four chairs, and the beds. SENTENCE_END',
#  u'SENTENCE_START uncle henry and aunt em had a big bed in one corner, and dorothy a little bed in another corner. SENTENCE_END',
#  u'SENTENCE_START there was no garret at all, and no cellar--except a small hole dug in the ground, called a cyclone cellar, where the family could go in case one of those great whirlwinds arose, mighty enough to crush any building in its path. SENTENCE_END',
#  u'SENTENCE_START it was reached by a trap door in the middle of the floor, from which a ladder led down into the small, dark hole. SENTENCE_END',
#  u'SENTENCE_START when dorothy stood in the doorway and looked around, she could see nothing but the great gray prairie on every side. SENTENCE_END',
#  u'SENTENCE_START not a tree nor a house broke the broad sweep of flat country that reached to the edge of the sky in all directions. SENTENCE_END',
#  u'SENTENCE_START the sun had baked the plowed land into a gray mass, with little cracks running through it. SENTENCE_END',
#  u'SENTENCE_START even the grass was not green, for the sun had burned the tops of the long blades until they were the same gray color to be seen everywhere. SENTENCE_END',
#  u'SENTENCE_START once the house had been painted, but the sun blistered the paint and the rains washed it away, and now the house was as dull and gray as everything else. SENTENCE_END',
#  u'SENTENCE_START when aunt em came there to live she was a young, pretty wife. SENTENCE_END',
#  u'SENTENCE_START the sun and wind had changed her, too. SENTENCE_END',
#  u'SENTENCE_START they had taken the sparkle from her eyes and left them a sober gray; they had taken the red from her cheeks and lips, and they were gray also. SENTENCE_END',
#  u'SENTENCE_START she was thin and gaunt, and never smiled now. SENTENCE_END',
#  u"SENTENCE_START when dorothy, who was an orphan, first came to her, aunt em had been so startled by the child's laughter that she would scream and press her hand upon her heart whenever dorothy's merry voice reached her ears; and she still looked at the little girl with wonder that she could find anything to laugh at. SENTENCE_END",
#  u'SENTENCE_START uncle henry never laughed. SENTENCE_END',
#  u'SENTENCE_START he worked hard from morning till night and did not know what joy was. SENTENCE_END',
#  u'SENTENCE_START he was gray also, from his long beard to his rough boots, and he looked stern and solemn, and rarely spoke. SENTENCE_END',
#  u'SENTENCE_START it was toto that made dorothy laugh, and saved her from growing as gray as her other surroundings. SENTENCE_END',
#  u'SENTENCE_START toto was not gray; he was a little black dog, with long silky hair and small black eyes that twinkled merrily on either side of his funny, wee nose. SENTENCE_END',
#  u'SENTENCE_START toto played all day long, and dorothy played with him, and loved him dearly. SENTENCE_END',
#  u'SENTENCE_START today, however, they were not playing. SENTENCE_END',
#  u'SENTENCE_START uncle henry sat upon the doorstep and looked anxiously at the sky, which was even grayer than usual. SENTENCE_END',
#  u'SENTENCE_START dorothy stood in the door with toto in her arms, and looked at the sky too. SENTENCE_END',
#  u'SENTENCE_START aunt em was washing the dishes. SENTENCE_END',
#  u'SENTENCE_START from the far north they heard a low wail of the wind, and uncle henry and dorothy could see where the long grass bowed in waves before the coming storm. SENTENCE_END',
#  u'SENTENCE_START there now came a sharp whistling in the air from the south, and as they turned their eyes that way they saw ripples in the grass coming from that direction also. SENTENCE_END',
#  u'SENTENCE_START suddenly uncle henry stood up. SENTENCE_END',
#  u'SENTENCE_START "there\'s a cyclone coming, em," he called to his wife. SENTENCE_END',
#  u'SENTENCE_START "i\'ll go look after the stock." SENTENCE_END',
#  u'SENTENCE_START then he ran toward the sheds where the cows and horses were kept. SENTENCE_END',
#  u'SENTENCE_START aunt em dropped her work and came to the door. SENTENCE_END',
#  u'SENTENCE_START one glance told her of the danger close at hand. SENTENCE_END',
#  u'SENTENCE_START "quick, dorothy!" SENTENCE_END',
#  u'SENTENCE_START she screamed. SENTENCE_END',
#  u'SENTENCE_START "run for the cellar!" SENTENCE_END',
#  u"SENTENCE_START toto jumped out of dorothy's arms and hid under the bed, and the girl started to get him. SENTENCE_END",
#  u'SENTENCE_START aunt em, badly frightened, threw open the trap door in the floor and climbed down the ladder into the small, dark hole. SENTENCE_END',
#  u'SENTENCE_START dorothy caught toto at last and started to follow her aunt. SENTENCE_END',
#  u'SENTENCE_START when she was halfway across the room there came a great shriek from the wind, and the house shook so hard that she lost her footing and sat down suddenly upon the floor. SENTENCE_END',
#  u'SENTENCE_START then a strange thing happened. SENTENCE_END',
#  u'SENTENCE_START the house whirled around two or three times and rose slowly through the air. SENTENCE_END',
#  u'SENTENCE_START dorothy felt as if she were going up in a balloon. SENTENCE_END',
#  u'SENTENCE_START the north and south winds met where the house stood, and made it the exact center of the cyclone. SENTENCE_END',
#  u'SENTENCE_START in the middle of a cyclone the air is generally still, but the great pressure of the wind on every side of the house raised it up higher and higher, until it was at the very top of the cyclone; and there it remained and was carried miles and miles away as easily as you could carry a feather. SENTENCE_END',
#  u'SENTENCE_START it was very dark, and the wind howled horribly around her, but dorothy found she was riding quite easily. SENTENCE_END',
#  u'SENTENCE_START after the first few whirls around, and one other time when the house tipped badly, she felt as if she were being rocked gently, like a baby in a cradle. SENTENCE_END',
#  u'SENTENCE_START toto did not like it. SENTENCE_END',
#  u'SENTENCE_START he ran about the room, now here, now there, barking loudly; but dorothy sat quite still on the floor and waited to see what would happen. SENTENCE_END',
#  u'SENTENCE_START once toto got too near the open trap door, and fell in; and at first the little girl thought she had lost him. SENTENCE_END',
#  u'SENTENCE_START but soon she saw one of his ears sticking up through the hole, for the strong pressure of the air was keeping him up so that he could not fall. SENTENCE_END',
#  u'SENTENCE_START she crept to the hole, caught toto by the ear, and dragged him into the room again, afterward closing the trap door so that no more accidents could happen. SENTENCE_END',
#  u'SENTENCE_START hour after hour passed away, and slowly dorothy got over her fright; but she felt quite lonely, and the wind shrieked so loudly all about her that she nearly became deaf. SENTENCE_END',
#  u'SENTENCE_START at first she had wondered if she would be dashed to pieces when the house fell again; but as the hours passed and nothing terrible happened, she stopped worrying and resolved to wait calmly and see what the future would bring. SENTENCE_END',
#  u'SENTENCE_START at last she crawled over the swaying floor to her bed, and lay down upon it; and toto followed and lay down beside her. SENTENCE_END',
#  u'SENTENCE_START in spite of the swaying of the house and the wailing of the wind, dorothy soon closed her eyes and fell fast asleep. SENTENCE_END',
#  u'SENTENCE_START 2.  the council with the munchkins   she was awakened by a shock, so sudden and severe that if dorothy had not been lying on the soft bed she might have been hurt. SENTENCE_END',
#  u'SENTENCE_START as it was, the jar made her catch her breath and wonder what had happened; and toto put his cold little nose into her face and whined dismally. SENTENCE_END',
#  u'SENTENCE_START dorothy sat up and noticed that the house was not moving; nor was it dark, for the bright sunshine came in at the window, flooding the little room. SENTENCE_END',
#  u'SENTENCE_START she sprang from her bed and with toto at her heels ran and opened the door. SENTENCE_END',
#  u'SENTENCE_START the little girl gave a cry of amazement and looked about her, her eyes growing bigger and bigger at the wonderful sights she saw. SENTENCE_END',
#  u'SENTENCE_START the cyclone had set the house down very gently--for a cyclone--in the midst of a country of marvelous beauty. SENTENCE_END',
#  u'SENTENCE_START there were lovely patches of greensward all about, with stately trees bearing rich and luscious fruits. SENTENCE_END',
#  u'SENTENCE_START banks of gorgeous flowers were on every hand, and birds with rare and brilliant plumage sang and fluttered in the trees and bushes. SENTENCE_END',
#  u'SENTENCE_START a little way off was a small brook, rushing and sparkling along between green banks, and murmuring in a voice very grateful to a little girl who had lived so long on the dry, gray prairies. SENTENCE_END',
#  u'SENTENCE_START while she stood looking eagerly at the strange and beautiful sights, she noticed coming toward her a group of the queerest people she had ever seen. SENTENCE_END',
#  u'SENTENCE_START they were not as big as the grown folk she had always been used to; but neither were they very small. SENTENCE_END',
#  u'SENTENCE_START in fact, they seemed about as tall as dorothy, who was a well-grown child for her age, although they were, so far as looks go, many years older. SENTENCE_END',
#  u'SENTENCE_START three were men and one a woman, and all were oddly dressed. SENTENCE_END',
#  u'SENTENCE_START they wore round hats that rose to a small point a foot above their heads, with little bells around the brims that tinkled sweetly as they moved. SENTENCE_END',
#  u"SENTENCE_START the hats of the men were blue; the little woman's hat was white, and she wore a white gown that hung in pleats from her shoulders. SENTENCE_END",
#  u'SENTENCE_START over it were sprinkled little stars that glistened in the sun like diamonds. SENTENCE_END',
#  u'SENTENCE_START the men were dressed in blue, of the same shade as their hats, and wore well-polished boots with a deep roll of blue at the tops. SENTENCE_END',
#  u'SENTENCE_START the men, dorothy thought, were about as old as uncle henry, for two of them had beards. SENTENCE_END',
#  u'SENTENCE_START but the little woman was doubtless much older. SENTENCE_END',
#  u'SENTENCE_START her face was covered with wrinkles, her hair was nearly white, and she walked rather stiffly. SENTENCE_END',
#  u'SENTENCE_START when these people drew near the house where dorothy was standing in the doorway, they paused and whispered among themselves, as if afraid to come farther. SENTENCE_END',
#  u'SENTENCE_START but the little old woman walked up to dorothy, made a low bow and said, in a sweet voice:  "you are welcome, most noble sorceress, to the land of the munchkins. SENTENCE_END',
#  u'SENTENCE_START we are so grateful to you for having killed the wicked witch of the east, and for setting our people free from bondage." SENTENCE_END',
#  u'SENTENCE_START dorothy listened to this speech with wonder. SENTENCE_END',
#  u'SENTENCE_START what could the little woman possibly mean by calling her a sorceress, and saying she had killed the wicked witch of the east? SENTENCE_END',
#  u'SENTENCE_START dorothy was an innocent, harmless little girl, who had been carried by a cyclone many miles from home; and she had never killed anything in all her life. SENTENCE_END',
#  u'SENTENCE_START but the little woman evidently expected her to answer; so dorothy said, with hesitation, "you are very kind, but there must be some mistake. SENTENCE_END',
#  u'SENTENCE_START i have not killed anything." SENTENCE_END',
#  u'SENTENCE_START "your house did, anyway," replied the little old woman, with a laugh, "and that is the same thing. SENTENCE_END',
#  u'SENTENCE_START see!" SENTENCE_END',
#  u'SENTENCE_START she continued, pointing to the corner of the house. SENTENCE_END',
#  u'SENTENCE_START "there are her two feet, still sticking out from under a block of wood." SENTENCE_END',
#  u'SENTENCE_START dorothy looked, and gave a little cry of fright. SENTENCE_END',
#  u'SENTENCE_START there, indeed, just under the corner of the great beam the house rested on, two feet were sticking out, shod in silver shoes with pointed toes. SENTENCE_END',
#  u'SENTENCE_START "oh, dear! SENTENCE_END',
#  u'SENTENCE_START oh, dear!" SENTENCE_END',
#  u'SENTENCE_START cried dorothy, clasping her hands together in dismay. SENTENCE_END',
#  u'SENTENCE_START "the house must have fallen on her. SENTENCE_END',
#  u'SENTENCE_START whatever shall we do?" SENTENCE_END',
#  u'SENTENCE_START "there is nothing to be done," said the little woman calmly. SENTENCE_END',
#  u'SENTENCE_START "but who was she?" SENTENCE_END',
#  u'SENTENCE_START asked dorothy. SENTENCE_END',
#  u'SENTENCE_START "she was the wicked witch of the east, as i said," answered the little woman. SENTENCE_END',
#  u'SENTENCE_START "she has held all the munchkins in bondage for many years, making them slave for her night and day. SENTENCE_END',
#  u'SENTENCE_START now they are all set free, and are grateful to you for the favor." SENTENCE_END',
#  u'SENTENCE_START "who are the munchkins?" SENTENCE_END',
#  u'SENTENCE_START inquired dorothy. SENTENCE_END',
#  u'SENTENCE_START "they are the people who live in this land of the east  where the wicked witch ruled." SENTENCE_END',
#  u'SENTENCE_START "are you a munchkin?" SENTENCE_END',
#  u'SENTENCE_START asked dorothy. SENTENCE_END',
#  u'SENTENCE_START "no, but i am their friend, although i live in the land of the north. SENTENCE_END',
#  u'SENTENCE_START when they saw the witch of the east was dead the munchkins sent a swift messenger to me, and i came at once. SENTENCE_END',
#  u'SENTENCE_START i am the witch of the north." SENTENCE_END',
#  u'SENTENCE_START "oh, gracious!" SENTENCE_END',
#  u'SENTENCE_START cried dorothy. SENTENCE_END',
#  u'SENTENCE_START "are you a real witch?" SENTENCE_END',
#  u'SENTENCE_START "yes, indeed," answered the little woman. SENTENCE_END',
#  u'SENTENCE_START "but i am a good witch, and the people love me. SENTENCE_END',
#  u'SENTENCE_START i am not as powerful as the wicked witch was who ruled here, or i should have set the people free myself." SENTENCE_END',
#  u'SENTENCE_START "but i thought all witches were wicked," said the girl, who was half frightened at facing a real witch. SENTENCE_END',
#  u'SENTENCE_START "oh, no, that is a great mistake. SENTENCE_END',
#  u'SENTENCE_START there were only four witches in all the land of oz, and two of them, those who live in the north and the south, are good witches. SENTENCE_END',
#  u'SENTENCE_START i know this is true, for i am one of them myself, and cannot be mistaken. SENTENCE_END',
#  u'SENTENCE_START those who dwelt in the east and the west were, indeed, wicked witches; but now that you have killed one of them, there is but one wicked witch in all the land of oz--the one who lives in the west." SENTENCE_END',
#  u'SENTENCE_START "but," said dorothy, after a moment\'s thought, "aunt em has told me that the witches were all dead--years and years ago." SENTENCE_END',
#  u'SENTENCE_START "who is aunt em?" SENTENCE_END',
#  u'SENTENCE_START inquired the little old woman. SENTENCE_END',
#  u'SENTENCE_START "she is my aunt who lives in kansas, where i came from." SENTENCE_END',
#  u'SENTENCE_START the witch of the north seemed to think for a time, with her head bowed and her eyes upon the ground. SENTENCE_END',
#  u'SENTENCE_START then she looked up and said, "i do not know where kansas is, for i have never heard that country mentioned before. SENTENCE_END',
#  u'SENTENCE_START but tell me, is it a civilized country?" SENTENCE_END',
#  u'SENTENCE_START "oh, yes," replied dorothy. SENTENCE_END',
#  u'SENTENCE_START "then that accounts for it. SENTENCE_END',
#  u'SENTENCE_START in the civilized countries i believe there are no witches left, nor wizards, nor sorceresses, nor magicians. SENTENCE_END',
#  u'SENTENCE_START but, you see, the land of oz has never been civilized, for we are cut off from all the rest of the world. SENTENCE_END',
#  u'SENTENCE_START therefore we still have witches and wizards amongst us." SENTENCE_END',
#  u'SENTENCE_START "who are the wizards?" SENTENCE_END',
#  u'SENTENCE_START asked dorothy. SENTENCE_END',
#  u'SENTENCE_START "oz himself is the great wizard," answered the witch, sinking her voice to a whisper. SENTENCE_END',
#  u'SENTENCE_START "he is more powerful than all the rest of us together. SENTENCE_END',
#  u'SENTENCE_START he lives in the city of emeralds." SENTENCE_END',
#  u'SENTENCE_START dorothy was going to ask another question, but just then the munchkins, who had been standing silently by, gave a loud shout and pointed to the corner of the house where the wicked witch had been lying. SENTENCE_END',
#  u'SENTENCE_START "what is it?" SENTENCE_END',
#  u'SENTENCE_START asked the little old woman, and looked, and began to laugh. SENTENCE_END',
#  u'SENTENCE_START the feet of the dead witch had disappeared entirely, and nothing was left but the silver shoes. SENTENCE_END',
#  u'SENTENCE_START "she was so old," explained the witch of the north, "that she dried up quickly in the sun. SENTENCE_END',
#  u'SENTENCE_START that is the end of her. SENTENCE_END',
#  u'SENTENCE_START but the silver shoes are yours, and you shall have them to wear." SENTENCE_END',
#  u'SENTENCE_START she reached down and picked up the shoes, and after shaking the dust out of them handed them to dorothy. SENTENCE_END',
#  u'SENTENCE_START "the witch of the east was proud of those silver shoes," said one of the munchkins, "and there is some charm connected with them; but what it is we never knew." SENTENCE_END',
#  u'SENTENCE_START dorothy carried the shoes into the house and placed them on the table. SENTENCE_END',
#  u'SENTENCE_START then she came out again to the munchkins and said:  "i am anxious to get back to my aunt and uncle, for i am sure they will worry about me. SENTENCE_END',
#  u'SENTENCE_START can you help me find my way?" SENTENCE_END',
#  u'SENTENCE_START the munchkins and the witch first looked at one another, and then at dorothy, and then shook their heads. SENTENCE_END',
#  u'SENTENCE_START "at the east, not far from here," said one, "there is a great desert, and none could live to cross it." SENTENCE_END',
#  u'SENTENCE_START "it is the same at the south," said another, "for i have been there and seen it. SENTENCE_END',
#  u'SENTENCE_START the south is the country of the quadlings." SENTENCE_END',
#  u'SENTENCE_START "i am told," said the third man, "that it is the same at the west. SENTENCE_END',
#  u'SENTENCE_START and that country, where the winkies live, is ruled by the wicked witch of the west, who would make you her slave if you passed her way." SENTENCE_END',
#  u'SENTENCE_START "the north is my home," said the old lady, "and at its edge is the same great desert that surrounds this land of oz. SENTENCE_END',
#  u'SENTENCE_START i\'m afraid, my dear, you will have to live with us." SENTENCE_END',
#  u'SENTENCE_START dorothy began to sob at this, for she felt lonely among all these strange people. SENTENCE_END',
#  u'SENTENCE_START her tears seemed to grieve the kind-hearted munchkins, for they immediately took out their handkerchiefs and began to weep also. SENTENCE_END',
#  u'SENTENCE_START as for the little old woman, she took off her cap and balanced the point on the end of her nose, while she counted "one, two, three" in a solemn voice. SENTENCE_END',
#  u'SENTENCE_START at once the cap changed to a slate, on which was written in big, white chalk marks:    "let dorothy go to the city of emeralds"   the little old woman took the slate from her nose, and having read the words on it, asked, "is your name dorothy, my dear?" SENTENCE_END',
#  u'SENTENCE_START "yes," answered the child, looking up and drying her tears. SENTENCE_END',
#  u'SENTENCE_START "then you must go to the city of emeralds. SENTENCE_END',
#  u'SENTENCE_START perhaps oz will help you." SENTENCE_END',
#  u'SENTENCE_START "where is this city?" SENTENCE_END',
#  u'SENTENCE_START asked dorothy. SENTENCE_END',
#  u'SENTENCE_START "it is exactly in the center of the country, and is ruled by oz, the great wizard i told you of." SENTENCE_END',
#  u'SENTENCE_START "is he a good man?" SENTENCE_END',
#  u'SENTENCE_START inquired the girl anxiously. SENTENCE_END',
#  u'SENTENCE_START "he is a good wizard. SENTENCE_END',
#  u'SENTENCE_START whether he is a man or not i cannot tell, for i have never seen him." SENTENCE_END',
#  u'SENTENCE_START "how can i get there?" SENTENCE_END',
#  u'SENTENCE_START asked dorothy. SENTENCE_END',
#  u'SENTENCE_START "you must walk. SENTENCE_END',
#  u'SENTENCE_START it is a long journey, through a country that is sometimes pleasant and sometimes dark and terrible. SENTENCE_END',
#  u'SENTENCE_START however, i will use all the magic arts i know of to keep you from harm." SENTENCE_END',
#  u'SENTENCE_START "won\'t you go with me?" SENTENCE_END',
#  u'SENTENCE_START pleaded the girl, who had begun to look upon the little old woman as her only friend. SENTENCE_END',
#  u'SENTENCE_START "no, i cannot do that," she replied, "but i will give you my kiss, and no one will dare injure a person who has been kissed by the witch of the north." SENTENCE_END',
#  u'SENTENCE_START she came close to dorothy and kissed her gently on the forehead. SENTENCE_END',
#  u'SENTENCE_START where her lips touched the girl they left a round, shining mark, as dorothy found out soon after. SENTENCE_END',
#  u'SENTENCE_START "the road to the city of emeralds is paved with yellow brick," said the witch, "so you cannot miss it. SENTENCE_END',
#  u'SENTENCE_START when you get to oz do not be afraid of him, but tell your story and ask him to help you. SENTENCE_END',
#  u'SENTENCE_START good-bye, my dear." SENTENCE_END',
#  u'SENTENCE_START the three munchkins bowed low to her and wished her a pleasant journey, after which they walked away through the trees. SENTENCE_END',
#  u'SENTENCE_START the witch gave dorothy a friendly little nod, whirled around on her left heel three times, and straightway disappeared, much to the surprise of little toto, who barked after her loudly enough when she had gone, because he had been afraid even to growl while she stood by. SENTENCE_END',
#  u'SENTENCE_START but dorothy, knowing her to be a witch, had expected her to disappear in just that way, and was not surprised in the least. SENTENCE_END',
#  u'SENTENCE_START 3.  how dorothy saved the scarecrow   when dorothy was left alone she began to feel hungry. SENTENCE_END',
#  u'SENTENCE_START so she went to the cupboard and cut herself some bread, which she spread with butter. SENTENCE_END',
#  u'SENTENCE_START she gave some to toto, and taking a pail from the shelf she carried it down to the little brook and filled it with clear, sparkling water. SENTENCE_END',
#  u'SENTENCE_START toto ran over to the trees and began to bark at the birds sitting there. SENTENCE_END',
#  u'SENTENCE_START dorothy went to get him, and saw such delicious fruit hanging from the branches that she gathered some of it, finding it just what she wanted to help out her breakfast. SENTENCE_END',
#  u'SENTENCE_START then she went back to the house, and having helped herself and toto to a good drink of the cool, clear water, she set about making ready for the journey to the city of emeralds. SENTENCE_END',
#  u'SENTENCE_START dorothy had only one other dress, but that happened to be clean and was hanging on a peg beside her bed. SENTENCE_END',
#  u'SENTENCE_START it was gingham, with checks of white and blue; and although the blue was somewhat faded with many washings, it was still a pretty frock. SENTENCE_END',
#  u'SENTENCE_START the girl washed herself carefully, dressed herself in the clean gingham, and tied her pink sunbonnet on her head. SENTENCE_END',
#  u'SENTENCE_START she took a little basket and filled it with bread from the cupboard, laying a white cloth over the top. SENTENCE_END',
#  u'SENTENCE_START then she looked down at her feet and noticed how old and worn her shoes were. SENTENCE_END',
#  u'SENTENCE_START "they surely will never do for a long journey, toto," she said. SENTENCE_END',
#  u'SENTENCE_START and toto looked up into her face with his little black eyes and wagged his tail to show he knew what she meant. SENTENCE_END',
#  u'SENTENCE_START at that moment dorothy saw lying on the table the silver shoes that had belonged to the witch of the east. SENTENCE_END',
#  u'SENTENCE_START "i wonder if they will fit me," she said to toto. SENTENCE_END',
#  u'SENTENCE_START "they would be just the thing to take a long walk in, for they could not wear out." SENTENCE_END',
#  u'SENTENCE_START she took off her old leather shoes and tried on the silver ones, which fitted her as well as if they had been made for her. SENTENCE_END',
#  u'SENTENCE_START finally she picked up her basket. SENTENCE_END',
#  u'SENTENCE_START "come along, toto," she said. SENTENCE_END',
#  u'SENTENCE_START "we will go to the emerald city and ask the great oz how to get back to kansas again." SENTENCE_END',
#  u'SENTENCE_START she closed the door, locked it, and put the key carefully in the pocket of her dress. SENTENCE_END',
#  u'SENTENCE_START and so, with toto trotting along soberly behind her, she started on her journey. SENTENCE_END',
#  u'SENTENCE_START there were several roads nearby, but it did not take her long to find the one paved with yellow bricks. SENTENCE_END',
#  u'SENTENCE_START within a short time she was walking briskly toward the emerald city, her silver shoes tinkling merrily on the hard, yellow road-bed. SENTENCE_END',
#  u'SENTENCE_START the sun shone bright and the birds sang sweetly, and dorothy did not feel nearly so bad as you might think a little girl would who had been suddenly whisked away from her own country and set down in the midst of a strange land. SENTENCE_END',
#  u'SENTENCE_START she was surprised, as she walked along, to see how pretty the country was about her. SENTENCE_END',
#  u'SENTENCE_START there were neat fences at the sides of the road, painted a dainty blue color, and beyond them were fields of grain and vegetables in abundance. SENTENCE_END',
#  u'SENTENCE_START evidently the munchkins were good farmers and able to raise large crops. SENTENCE_END',
#  u'SENTENCE_START once in a while she would pass a house, and the people came out to look at her and bow low as she went by; for everyone knew she had been the means of destroying the wicked witch and setting them free from bondage. SENTENCE_END',
#  u'SENTENCE_START the houses of the munchkins were odd-looking dwellings, for each was round, with a big dome for a roof. SENTENCE_END',
#  u'SENTENCE_START all were painted blue, for in this country of the east blue was the favorite color. SENTENCE_END',
#  u'SENTENCE_START toward evening, when dorothy was tired with her long walk and began to wonder where she should pass the night, she came to a house rather larger than the rest. SENTENCE_END',
#  u'SENTENCE_START on the green lawn before it many men and women were dancing. SENTENCE_END',
#  u'SENTENCE_START five little fiddlers played as loudly as possible, and the people were laughing and singing, while a big table near by was loaded with delicious fruits and nuts, pies and cakes, and many other good things to eat. SENTENCE_END',
#  u'SENTENCE_START the people greeted dorothy kindly, and invited her to supper and to pass the night with them; for this was the home of one of the richest munchkins in the land, and his friends were gathered with him to celebrate their freedom from the bondage of the wicked witch. SENTENCE_END',
#  u'SENTENCE_START dorothy ate a hearty supper and was waited upon by the rich munchkin himself, whose name was boq. SENTENCE_END',
#  u'SENTENCE_START then she sat upon a settee and watched the people dance. SENTENCE_END',
#  u'SENTENCE_START when boq saw her silver shoes he said, "you must be a great sorceress." SENTENCE_END',
#  u'SENTENCE_START "why?" SENTENCE_END',
#  u'SENTENCE_START asked the girl. SENTENCE_END',
#  u'SENTENCE_START "because you wear silver shoes and have killed the wicked witch. SENTENCE_END',
#  u'SENTENCE_START besides, you have white in your frock, and only witches and sorceresses wear white." SENTENCE_END',
#  u'SENTENCE_START "my dress is blue and white checked," said dorothy, smoothing out the wrinkles in it. SENTENCE_END',
#  u'SENTENCE_START "it is kind of you to wear that," said boq. SENTENCE_END',
#  u'SENTENCE_START "blue is the color of the munchkins, and white is the witch color. SENTENCE_END',
#  u'SENTENCE_START so we know you are a friendly witch." SENTENCE_END',
#  u'SENTENCE_START dorothy did not know what to say to this, for all the people seemed to think her a witch, and she knew very well she was only an ordinary little girl who had come by the chance of a cyclone into a strange land. SENTENCE_END',
#  u'SENTENCE_START when she had tired watching the dancing, boq led her into the house, where he gave her a room with a pretty bed in it. SENTENCE_END',
#  u'SENTENCE_START the sheets were made of blue cloth, and dorothy slept soundly in them till morning, with toto curled up on the blue rug beside her. SENTENCE_END',
#  u'SENTENCE_START she ate a hearty breakfast, and watched a wee munchkin baby, who played with toto and pulled his tail and crowed and laughed in a way that greatly amused dorothy. SENTENCE_END',
#  u'SENTENCE_START toto was a fine curiosity to all the people, for they had never seen a dog before. SENTENCE_END',
#  u'SENTENCE_START "how far is it to the emerald city?" SENTENCE_END',
#  u'SENTENCE_START the girl asked. SENTENCE_END',
#  u'SENTENCE_START "i do not know," answered boq gravely, "for i have never been there. SENTENCE_END',
#  u'SENTENCE_START it is better for people to keep away from oz, unless they have business with him. SENTENCE_END',
#  u'SENTENCE_START but it is a long way to the emerald city, and it will take you many days. SENTENCE_END',
#  u'SENTENCE_START the country here is rich and pleasant, but you must pass through rough and dangerous places before you reach the end of your journey." SENTENCE_END',
#  u'SENTENCE_START this worried dorothy a little, but she knew that only the great oz could help her get to kansas again, so she bravely resolved not to turn back. SENTENCE_END',
#  u'SENTENCE_START she bade her friends good-bye, and again started along the road of yellow brick. SENTENCE_END',
#  u'SENTENCE_START when she had gone several miles she thought she would stop to rest, and so climbed to the top of the fence beside the road and sat down. SENTENCE_END',
#  u'SENTENCE_START there was a great cornfield beyond the fence, and not far away she saw a scarecrow, placed high on a pole to keep the birds from the ripe corn. SENTENCE_END',
#  u'SENTENCE_START dorothy leaned her chin upon her hand and gazed thoughtfully at the scarecrow. SENTENCE_END',
#  u'SENTENCE_START its head was a small sack stuffed with straw, with eyes, nose, and mouth painted on it to represent a face. SENTENCE_END',
#  u'SENTENCE_START an old, pointed blue hat, that had belonged to some munchkin, was perched on his head, and the rest of the figure was a blue suit of clothes, worn and faded, which had also been stuffed with straw. SENTENCE_END',
#  u'SENTENCE_START on the feet were some old boots with blue tops, such as every man wore in this country, and the figure was raised above the stalks of corn by means of the pole stuck up its back. SENTENCE_END',
#  u'SENTENCE_START while dorothy was looking earnestly into the queer, painted face of the scarecrow, she was surprised to see one of the eyes slowly wink at her. SENTENCE_END',
#  u'SENTENCE_START she thought she must have been mistaken at first, for none of the scarecrows in kansas ever wink; but presently the figure nodded its head to her in a friendly way. SENTENCE_END',
#  u'SENTENCE_START then she climbed down from the fence and walked up to it, while toto ran around the pole and barked. SENTENCE_END',
#  u'SENTENCE_START "good day," said the scarecrow, in a rather husky voice. SENTENCE_END',
#  u'SENTENCE_START "did you speak?" SENTENCE_END',
#  u'SENTENCE_START asked the girl, in wonder. SENTENCE_END',
#  u'SENTENCE_START "certainly," answered the scarecrow. SENTENCE_END',
#  u'SENTENCE_START "how do you do?" SENTENCE_END',
#  u'SENTENCE_START "i\'m pretty well, thank you," replied dorothy politely. SENTENCE_END',
#  u'SENTENCE_START "how do you do?" SENTENCE_END',
#  u'SENTENCE_START "i\'m not feeling well," said the scarecrow, with a smile, "for it is very tedious being perched up here night and day to scare away crows." SENTENCE_END',
#  u'SENTENCE_START "can\'t you get down?" SENTENCE_END',
#  u'SENTENCE_START asked dorothy. SENTENCE_END',
#  u'SENTENCE_START "no, for this pole is stuck up my back. SENTENCE_END',
#  u'SENTENCE_START if you will please take away the pole i shall be greatly obliged to you." SENTENCE_END',
#  u'SENTENCE_START dorothy reached up both arms and lifted the figure off the pole, for, being stuffed with straw, it was quite light. SENTENCE_END',
#  u'SENTENCE_START "thank you very much," said the scarecrow, when he had been set down on the ground. SENTENCE_END',
#  u'SENTENCE_START "i feel like a new man." SENTENCE_END',
#  u'SENTENCE_START dorothy was puzzled at this, for it sounded queer to hear a stuffed man speak, and to see him bow and walk along beside her. SENTENCE_END',
#  u'SENTENCE_START "who are you?" SENTENCE_END',
#  u'SENTENCE_START asked the scarecrow when he had stretched himself and yawned. SENTENCE_END',
#  u'SENTENCE_START "and where are you going?" SENTENCE_END',
#  u'SENTENCE_START "my name is dorothy," said the girl, "and i am going to the emerald city, to ask the great oz to send me back to kansas." SENTENCE_END',
#  u'SENTENCE_START "where is the emerald city?" SENTENCE_END',
#  u'SENTENCE_START he inquired. SENTENCE_END',
#  u'SENTENCE_START "and who is oz?" SENTENCE_END',
#  u'SENTENCE_START "why, don\'t you know?" SENTENCE_END',
#  u'SENTENCE_START she returned, in surprise. SENTENCE_END',
#  u'SENTENCE_START "no, indeed. SENTENCE_END',
#  u"SENTENCE_START i don't know anything. SENTENCE_END",
#  u'SENTENCE_START you see, i am stuffed, so i have no brains at all," he answered sadly. SENTENCE_END',
#  u'SENTENCE_START "oh," said dorothy, "i\'m awfully sorry for you." SENTENCE_END',
#  u'SENTENCE_START "do you think," he asked, "if i go to the emerald city with you, that oz would give me some brains?" SENTENCE_END',
#  u'SENTENCE_START "i cannot tell," she returned, "but you may come with me, if you like. SENTENCE_END',
#  u'SENTENCE_START if oz will not give you any brains you will be no worse off than you are now." SENTENCE_END',
#  u'SENTENCE_START "that is true," said the scarecrow. SENTENCE_END',
#  u'SENTENCE_START "you see," he continued confidentially, "i don\'t mind my legs and arms and body being stuffed, because i cannot get hurt. SENTENCE_END',
#  u"SENTENCE_START if anyone treads on my toes or sticks a pin into me, it doesn't matter, for i can't feel it. SENTENCE_END",
#  u'SENTENCE_START but i do not want people to call me a fool, and if my head stays stuffed with straw instead of with brains, as yours is, how am i ever to know anything?" SENTENCE_END',
#  u'SENTENCE_START "i understand how you feel," said the little girl, who was truly sorry for him. SENTENCE_END',
#  u'SENTENCE_START "if you will come with me i\'ll ask oz to do all he can for you." SENTENCE_END',
#  u'SENTENCE_START "thank you," he answered gratefully. SENTENCE_END',
#  u'SENTENCE_START they walked back to the road. SENTENCE_END',
#  u'SENTENCE_START dorothy helped him over the fence, and they started along the path of yellow brick for the emerald city. SENTENCE_END',
#  u'SENTENCE_START toto did not like this addition to the party at first. SENTENCE_END',
#  u'SENTENCE_START he smelled around the stuffed man as if he suspected there might be a nest of rats in the straw, and he often growled in an unfriendly way at the scarecrow. SENTENCE_END',
#  u'SENTENCE_START "don\'t mind toto," said dorothy to her new friend. SENTENCE_END',
#  u'SENTENCE_START "he never bites." SENTENCE_END',
#  u'SENTENCE_START "oh, i\'m not afraid," replied the scarecrow. SENTENCE_END',
#  u'SENTENCE_START "he can\'t hurt the straw. SENTENCE_END',
#  u'SENTENCE_START do let me carry that basket for you. SENTENCE_END',
#  u"SENTENCE_START i shall not mind it, for i can't get tired. SENTENCE_END",
#  u'SENTENCE_START i\'ll tell you a secret," he continued, as he walked along. SENTENCE_END',
#  u'SENTENCE_START "there is only one thing in the world i am afraid of." SENTENCE_END',
#  u'SENTENCE_START "what is that?" SENTENCE_END',
#  u'SENTENCE_START asked dorothy; "the munchkin farmer who made you?" SENTENCE_END',
#  u'SENTENCE_START "no," answered the scarecrow; "it\'s a lighted match." SENTENCE_END',
#  u'SENTENCE_START 4.  the road through the forest   after a few hours the road began to be rough, and the walking grew so difficult that the scarecrow often stumbled over the yellow bricks, which were here very uneven. SENTENCE_END',
#  u'SENTENCE_START sometimes, indeed, they were broken or missing altogether, leaving holes that toto jumped across and dorothy walked around. SENTENCE_END',
#  u'SENTENCE_START as for the scarecrow, having no brains, he walked straight ahead, and so stepped into the holes and fell at full length on the hard bricks. SENTENCE_END',
#  u'SENTENCE_START it never hurt him, however, and dorothy would pick him up and set him upon his feet again, while he joined her in laughing merrily at his own mishap. SENTENCE_END',
#  u'SENTENCE_START the farms were not nearly so well cared for here as they were farther back. SENTENCE_END',
#  u'SENTENCE_START there were fewer houses and fewer fruit trees, and the farther they went the more dismal and lonesome the country became. SENTENCE_END',
#  u'SENTENCE_START at noon they sat down by the roadside, near a little brook, and dorothy opened her basket and got out some bread. SENTENCE_END',
#  u'SENTENCE_START she offered a piece to the scarecrow, but he refused. SENTENCE_END',
#  u'SENTENCE_START "i am never hungry," he said, "and it is a lucky thing i am not, for my mouth is only painted, and if i should cut a hole in it so i could eat, the straw i am stuffed with would come out, and that would spoil the shape of my head." SENTENCE_END',
#  u'SENTENCE_START dorothy saw at once that this was true, so she only nodded and went on eating her bread. SENTENCE_END',
#  u'SENTENCE_START "tell me something about yourself and the country you came from," said the scarecrow, when she had finished her dinner. SENTENCE_END',
#  u'SENTENCE_START so she told him all about kansas, and how gray everything was there, and how the cyclone had carried her to this queer land of oz. SENTENCE_END',
#  u'SENTENCE_START the scarecrow listened carefully, and said, "i cannot understand why you should wish to leave this beautiful country and go back to the dry, gray place you call kansas." SENTENCE_END',
#  u'SENTENCE_START "that is because you have no brains" answered the girl. SENTENCE_END',
#  u'SENTENCE_START "no matter how dreary and gray our homes are, we people of flesh and blood would rather live there than in any other country, be it ever so beautiful. SENTENCE_END',
#  u'SENTENCE_START there is no place like home." SENTENCE_END',
#  u'SENTENCE_START the scarecrow sighed. SENTENCE_END',
#  u'SENTENCE_START "of course i cannot understand it," he said. SENTENCE_END',
#  u'SENTENCE_START "if your heads were stuffed with straw, like mine, you would probably all live in the beautiful places, and then kansas would have no people at all. SENTENCE_END',
#  u'SENTENCE_START it is fortunate for kansas that you have brains." SENTENCE_END',
#  u'SENTENCE_START "won\'t you tell me a story, while we are resting?" SENTENCE_END',
#  u'SENTENCE_START asked the child. SENTENCE_END',
#  u'SENTENCE_START the scarecrow looked at her reproachfully, and answered:  "my life has been so short that i really know nothing whatever. SENTENCE_END',
#  u'SENTENCE_START i was only made day before yesterday. SENTENCE_END',
#  u'SENTENCE_START what happened in the world before that time is all unknown to me. SENTENCE_END',
#  u'SENTENCE_START luckily, when the farmer made my head, one of the first things he did was to paint my ears, so that i heard what was going on. SENTENCE_END',
#  u"SENTENCE_START there was another munchkin with him, and the first thing i heard was the farmer saying, 'how do you like those ears?' SENTENCE_END",
#  u'SENTENCE_START "\'they aren\'t straight,\'" answered the other. SENTENCE_END',
#  u'SENTENCE_START "\'never mind,\'" said the farmer. SENTENCE_END',
#  u'SENTENCE_START "\'they are ears just the same,\'" which was true enough. SENTENCE_END',
#  u'SENTENCE_START "\'now i\'ll make the eyes,\'" said the farmer. SENTENCE_END',
#  u'SENTENCE_START so he painted my right eye, and as soon as it was finished i found myself looking at him and at everything around me with a great deal of curiosity, for this was my first glimpse of the world. SENTENCE_END',
#  u'SENTENCE_START "\'that\'s a rather pretty eye,\'" remarked the munchkin who was watching the farmer. SENTENCE_END',
#  u'SENTENCE_START "\'blue paint is just the color for eyes.\' SENTENCE_END',
#  u'SENTENCE_START "\'i think i\'ll make the other a little bigger,\'" said the farmer. SENTENCE_END',
#  u'SENTENCE_START and when the second eye was done i could see much better than before. SENTENCE_END',
#  u'SENTENCE_START then he made my nose and my mouth. SENTENCE_END',
#  u"SENTENCE_START but i did not speak, because at that time i didn't know what a mouth was for. SENTENCE_END",
#  u'SENTENCE_START i had the fun of watching them make my body and my arms and legs; and when they fastened on my head, at last, i felt very proud, for i thought i was just as good a man as anyone. SENTENCE_END',
#  u'SENTENCE_START "\'this fellow will scare the crows fast enough,\' said the farmer. SENTENCE_END',
#  u"SENTENCE_START 'he looks just like a man.' SENTENCE_END",
#  u'SENTENCE_START "\'why, he is a man,\' said the other, and i quite agreed with him. SENTENCE_END',
#  u'SENTENCE_START the farmer carried me under his arm to the cornfield, and set me up on a tall stick, where you found me. SENTENCE_END',
#  u'SENTENCE_START he and his friend soon after walked away and left me alone. SENTENCE_END',
#  u'SENTENCE_START "i did not like to be deserted this way. SENTENCE_END',
#  u'SENTENCE_START so i tried to walk after them. SENTENCE_END',
#  u'SENTENCE_START but my feet would not touch the ground, and i was forced to stay on that pole. SENTENCE_END',
#  u'SENTENCE_START it was a lonely life to lead, for i had nothing to think of, having been made such a little while before. SENTENCE_END',
#  u'SENTENCE_START many crows and other birds flew into the cornfield, but as soon as they saw me they flew away again, thinking i was a munchkin; and this pleased me and made me feel that i was quite an important person. SENTENCE_END',
#  u'SENTENCE_START by and by an old crow flew near me, and after looking at me carefully he perched upon my shoulder and said:  "\'i wonder if that farmer thought to fool me in this clumsy manner. SENTENCE_END',
#  u"SENTENCE_START any crow of sense could see that you are only stuffed with straw.' SENTENCE_END",
#  u'SENTENCE_START then he hopped down at my feet and ate all the corn he wanted. SENTENCE_END',
#  u'SENTENCE_START the other birds, seeing he was not harmed by me, came to eat the corn too, so in a short time there was a great flock of them about me. SENTENCE_END',
#  u'SENTENCE_START "i felt sad at this, for it showed i was not such a good scarecrow after all; but the old crow comforted me, saying, \'if you only had brains in your head you would be as good a man as any of them, and a better man than some of them. SENTENCE_END',
#  u"SENTENCE_START brains are the only things worth having in this world, no matter whether one is a crow or a man.' SENTENCE_END",
#  u'SENTENCE_START "after the crows had gone i thought this over, and decided i would try hard to get some brains. SENTENCE_END',
#  u'SENTENCE_START by good luck you came along and pulled me off the stake, and from what you say i am sure the great oz will give me brains as soon as we get to the emerald city." SENTENCE_END',
#  u'SENTENCE_START "i hope so," said dorothy earnestly, "since you seem anxious to have them." SENTENCE_END',
#  u'SENTENCE_START "oh, yes; i am anxious," returned the scarecrow. SENTENCE_END',
#  u'SENTENCE_START "it is such an uncomfortable feeling to know one is a fool." SENTENCE_END',
#  u'SENTENCE_START "well," said the girl, "let us go." SENTENCE_END',
#  u'SENTENCE_START and she handed the basket to the scarecrow. SENTENCE_END',
#  u'SENTENCE_START there were no fences at all by the roadside now, and the land was rough and untilled. SENTENCE_END',
#  u'SENTENCE_START toward evening they came to a great forest, where the trees grew so big and close together that their branches met over the road of yellow brick. SENTENCE_END',
#  u'SENTENCE_START it was almost dark under the trees, for the branches shut out the daylight; but the travelers did not stop, and went on into the forest. SENTENCE_END',
#  u'SENTENCE_START "if this road goes in, it must come out," said the scarecrow, "and as the emerald city is at the other end of the road, we must go wherever it leads us." SENTENCE_END',
#  u'SENTENCE_START "anyone would know that," said dorothy. SENTENCE_END',
#  u'SENTENCE_START "certainly; that is why i know it," returned the scarecrow. SENTENCE_END',
#  u'SENTENCE_START "if it required brains to figure it out, i never should have said it." SENTENCE_END',
#  u'SENTENCE_START after an hour or so the light faded away, and they found themselves stumbling along in the darkness. SENTENCE_END',
#  u'SENTENCE_START dorothy could not see at all, but toto could, for some dogs see very well in the dark; and the scarecrow declared he could see as well as by day. SENTENCE_END',
#  u'SENTENCE_START so she took hold of his arm and managed to get along fairly well. SENTENCE_END',
#  u'SENTENCE_START "if you see any house, or any place where we can pass the night," she said, "you must tell me; for it is very uncomfortable walking in the dark." SENTENCE_END',
#  u'SENTENCE_START soon after the scarecrow stopped. SENTENCE_END',
#  u'SENTENCE_START "i see a little cottage at the right of us," he said, "built of logs and branches. SENTENCE_END',
# ...
#  u'SENTENCE_START the road was smooth and well paved, now, and the country about was beautiful, so that the travelers rejoiced in leaving the forest far behind, and with it the many dangers they had met in its gloomy shades. SENTENCE_END',
#  u'SENTENCE_START once more they could see fences built beside the road; but these were painted green, and when they came to a small house, in which a farmer evidently lived, that also was painted green. SENTENCE_END',
#  u'SENTENCE_START they passed by several of these houses during the afternoon, and sometimes people came to the doors and looked at them as if they would like to ask questions; but no one came near them nor spoke to them because of the great lion, of which they were very much afraid. SENTENCE_END',
#  u'SENTENCE_START the people were all dressed in clothing of a lovely emerald-green color and wore peaked hats like those of the munchkins. SENTENCE_END',
#  u'SENTENCE_START "this must be the land of oz," said dorothy, "and we are surely getting near the emerald city." SENTENCE_END',
#  u'SENTENCE_START "yes," answered the scarecrow. SENTENCE_END',
#  u'SENTENCE_START "everything is green here, while in the country of the munchkins blue was the favorite color. SENTENCE_END',
#  u'SENTENCE_START but the people do not seem to be as friendly as the munchkins, and i\'m afraid we shall be unable to find a place to pass the night." SENTENCE_END',
#  u'SENTENCE_START "i should like something to eat besides fruit," said the girl, "and i\'m sure toto is nearly starved. SENTENCE_END',
#  u'SENTENCE_START let us stop at the next house and talk to the people." SENTENCE_END',
#  u'SENTENCE_START so, when they came to a good-sized farmhouse, dorothy walked boldly up to the door and knocked. SENTENCE_END',
#  u'SENTENCE_START a woman opened it just far enough to look out, and said, "what do you want, child, and why is that great lion with you?" SENTENCE_END',
#  u'SENTENCE_START "we wish to pass the night with you, if you will allow us," answered dorothy; "and the lion is my friend and comrade, and would not hurt you for the world." SENTENCE_END',
#  u'SENTENCE_START "is he tame?" SENTENCE_END',
#  u'SENTENCE_START asked the woman, opening the door a little wider. SENTENCE_END',
#  u'SENTENCE_START "oh, yes," said the girl, "and he is a great coward, too. SENTENCE_END',
#  u'SENTENCE_START he will be more afraid of you than you are of him." SENTENCE_END',
#  u'SENTENCE_START "well," said the woman, after thinking it over and taking another peep at the lion, "if that is the case you may come in, and i will give you some supper and a place to sleep." SENTENCE_END',
#  u'SENTENCE_START so they all entered the house, where there were, besides the woman, two children and a man. SENTENCE_END',
#  u'SENTENCE_START the man had hurt his leg, and was lying on the couch in a corner. SENTENCE_END',
#  u'SENTENCE_START they seemed greatly surprised to see so strange a company, and while the woman was busy laying the table the man asked:  "where are you all going?" SENTENCE_END',
#  u'SENTENCE_START "to the emerald city," said dorothy, "to see the great oz." SENTENCE_END',
#  u'SENTENCE_START "oh, indeed!" SENTENCE_END',
#  u'SENTENCE_START exclaimed the man. SENTENCE_END',
#  u'SENTENCE_START "are you sure that oz will see you?" SENTENCE_END',
#  u'SENTENCE_START "why not?" SENTENCE_END',
#  u'SENTENCE_START she replied. SENTENCE_END',
#  u'SENTENCE_START "why, it is said that he never lets anyone come into his presence. SENTENCE_END',
#  u'SENTENCE_START i have been to the emerald city many times, and it is a beautiful and wonderful place; but i have never been permitted to see the great oz, nor do i know of any living person who has seen him." SENTENCE_END',
#  u'SENTENCE_START "does he never go out?" SENTENCE_END',
#  u'SENTENCE_START asked the scarecrow. SENTENCE_END',
#  u'SENTENCE_START "never. SENTENCE_END',
#  u'SENTENCE_START he sits day after day in the great throne room of his palace, and even those who wait upon him do not see him face to face." SENTENCE_END',
#  u'SENTENCE_START "what is he like?" SENTENCE_END',
#  u'SENTENCE_START asked the girl. SENTENCE_END',
#  u'SENTENCE_START "that is hard to tell," said the man thoughtfully. SENTENCE_END',
#  u'SENTENCE_START "you see, oz is a great wizard, and can take on any form he wishes. SENTENCE_END',
#  u'SENTENCE_START so that some say he looks like a bird; and some say he looks like an elephant; and some say he looks like a cat. SENTENCE_END',
#  u'SENTENCE_START to others he appears as a beautiful fairy, or a brownie, or in any other form that pleases him. SENTENCE_END',
#  u'SENTENCE_START but who the real oz is, when he is in his own form, no living person can tell." SENTENCE_END',
#  u'SENTENCE_START "that is very strange," said dorothy, "but we must try, in some way, to see him, or we shall have made our journey for nothing." SENTENCE_END',
#  u'SENTENCE_START "why do you wish to see the terrible oz?" SENTENCE_END',
#  u'SENTENCE_START asked the man. SENTENCE_END',
#  u'SENTENCE_START "i want him to give me some brains," said the scarecrow eagerly. SENTENCE_END',
#  u'SENTENCE_START "oh, oz could do that easily enough," declared the man. SENTENCE_END',
#  u'SENTENCE_START "he has more brains than he needs." SENTENCE_END',
#  u'SENTENCE_START "and i want him to give me a heart," said the tin woodman. SENTENCE_END',
#  u'SENTENCE_START "that will not trouble him," continued the man, "for oz has a large collection of hearts, of all sizes and shapes." SENTENCE_END',
#  u'SENTENCE_START "and i want him to give me courage," said the cowardly lion. SENTENCE_END',
#  u'SENTENCE_START "oz keeps a great pot of courage in his throne room," said the man, "which he has covered with a golden plate, to keep it from running over. SENTENCE_END',
#  u'SENTENCE_START he will be glad to give you some." SENTENCE_END',
#  u'SENTENCE_START "and i want him to send me back to kansas," said dorothy. SENTENCE_END',
#  u'SENTENCE_START "where is kansas?" SENTENCE_END',
#  u'SENTENCE_START asked the man, with surprise. SENTENCE_END',
#  u'SENTENCE_START "i don\'t know," replied dorothy sorrowfully, "but it is my home, and i\'m sure it\'s somewhere." SENTENCE_END',
#  u'SENTENCE_START "very likely. SENTENCE_END',
#  u'SENTENCE_START well, oz can do anything; so i suppose he will find kansas for you. SENTENCE_END',
#  u'SENTENCE_START but first you must get to see him, and that will be a hard task; for the great wizard does not like to see anyone, and he usually has his own way. SENTENCE_END',
#  u'SENTENCE_START but what do you want?" SENTENCE_END',
#  u'SENTENCE_START he continued, speaking to toto. SENTENCE_END',
#  u'SENTENCE_START toto only wagged his tail; for, strange to say, he could not speak. SENTENCE_END',
#  u'SENTENCE_START the woman now called to them that supper was ready, so they gathered around the table and dorothy ate some delicious porridge and a dish of scrambled eggs and a plate of nice white bread, and enjoyed her meal. SENTENCE_END',
#  u'SENTENCE_START the lion ate some of the porridge, but did not care for it, saying it was made from oats and oats were food for horses, not for lions. SENTENCE_END',
#  u'SENTENCE_START the scarecrow and the tin woodman ate nothing at all. SENTENCE_END',
#  u'SENTENCE_START toto ate a little of everything, and was glad to get a good supper again. SENTENCE_END',
#  u'SENTENCE_START the woman now gave dorothy a bed to sleep in, and toto lay down beside her, while the lion guarded the door of her room so she might not be disturbed. SENTENCE_END',
#  u'SENTENCE_START the scarecrow and the tin woodman stood up in a corner and kept quiet all night, although of course they could not sleep. SENTENCE_END',
#  u'SENTENCE_START the next morning, as soon as the sun was up, they started on their way, and soon saw a beautiful green glow in the sky just before them. SENTENCE_END',
#  u'SENTENCE_START "that must be the emerald city," said dorothy. SENTENCE_END',
#  u'SENTENCE_START as they walked on, the green glow became brighter and brighter, and it seemed that at last they were nearing the end of their travels. SENTENCE_END',
#  u'SENTENCE_START yet it was afternoon before they came to the great wall that surrounded the city. SENTENCE_END',
#  u'SENTENCE_START it was high and thick and of a bright green color. SENTENCE_END',
#  u'SENTENCE_START in front of them, and at the end of the road of yellow brick, was a big gate, all studded with emeralds that glittered so in the sun that even the painted eyes of the scarecrow were dazzled by their brilliancy. SENTENCE_END',
#  u'SENTENCE_START there was a bell beside the gate, and dorothy pushed the button and heard a silvery tinkle sound within. SENTENCE_END',
#  u'SENTENCE_START then the big gate swung slowly open, and they all passed through and found themselves in a high arched room, the walls of which glistened with countless emeralds. SENTENCE_END',
#  u'SENTENCE_START before them stood a little man about the same size as the munchkins. SENTENCE_END',
#  u'SENTENCE_START he was clothed all in green, from his head to his feet, and even his skin was of a greenish tint. SENTENCE_END',
#  u'SENTENCE_START at his side was a large green box. SENTENCE_END',
#  u'SENTENCE_START when he saw dorothy and her companions the man asked, "what do you wish in the emerald city?" SENTENCE_END',
#  u'SENTENCE_START "we came here to see the great oz," said dorothy. SENTENCE_END',
#  u'SENTENCE_START the man was so surprised at this answer that he sat down to think it over. SENTENCE_END',
#  u'SENTENCE_START "it has been many years since anyone asked me to see oz," he said, shaking his head in perplexity. SENTENCE_END',
#  u'SENTENCE_START "he is powerful and terrible, and if you come on an idle or foolish errand to bother the wise reflections of the great wizard, he might be angry and destroy you all in an instant." SENTENCE_END',
#  u'SENTENCE_START "but it is not a foolish errand, nor an idle one," replied the scarecrow; "it is important. SENTENCE_END',
#  u'SENTENCE_START and we have been told that oz is a good wizard." SENTENCE_END',
#  u'SENTENCE_START "so he is," said the green man, "and he rules the emerald city wisely and well. SENTENCE_END',
#  u'SENTENCE_START but to those who are not honest, or who approach him from curiosity, he is most terrible, and few have ever dared ask to see his face. SENTENCE_END',
#  u'SENTENCE_START i am the guardian of the gates, and since you demand to see the great oz i must take you to his palace. SENTENCE_END',
#  u'SENTENCE_START but first you must put on the spectacles." SENTENCE_END',
#  u'SENTENCE_START "why?" SENTENCE_END',
#  u'SENTENCE_START asked dorothy. SENTENCE_END',
#  u'SENTENCE_START "because if you did not wear spectacles the brightness and glory of the emerald city would blind you. SENTENCE_END',
#  u'SENTENCE_START even those who live in the city must wear spectacles night and day. SENTENCE_END',
#  u'SENTENCE_START they are all locked on, for oz so ordered it when the city was first built, and i have the only key that will unlock them." SENTENCE_END',
#  u'SENTENCE_START he opened the big box, and dorothy saw that it was filled with spectacles of every size and shape. SENTENCE_END',
#  u'SENTENCE_START all of them had green glasses in them. SENTENCE_END',
#  u'SENTENCE_START the guardian of the gates found a pair that would just fit dorothy and put them over her eyes. SENTENCE_END',
#  u'SENTENCE_START there were two golden bands fastened to them that passed around the back of her head, where they were locked together by a little key that was at the end of a chain the guardian of the gates wore around his neck. SENTENCE_END',
#  u'SENTENCE_START when they were on, dorothy could not take them off had she wished, but of course she did not wish to be blinded by the glare of the emerald city, so she said nothing. SENTENCE_END',
#  u'SENTENCE_START then the green man fitted spectacles for the scarecrow and the tin woodman and the lion, and even on little toto; and all were locked fast with the key. SENTENCE_END',
#  u'SENTENCE_START then the guardian of the gates put on his own glasses and told them he was ready to show them to the palace. SENTENCE_END',
#  u'SENTENCE_START taking a big golden key from a peg on the wall, he opened another gate, and they all followed him through the portal into the streets of the emerald city. SENTENCE_END',
#  u'SENTENCE_START 11.  the wonderful city of oz   even with eyes protected by the green spectacles, dorothy and her friends were at first dazzled by the brilliancy of the wonderful city. SENTENCE_END',
#  u'SENTENCE_START the streets were lined with beautiful houses all built of green marble and studded everywhere with sparkling emeralds. SENTENCE_END',
#  u'SENTENCE_START they walked over a pavement of the same green marble, and where the blocks were joined together were rows of emeralds, set closely, and glittering in the brightness of the sun. SENTENCE_END',
#  u'SENTENCE_START the window panes were of green glass; even the sky above the city had a green tint, and the rays of the sun were green. SENTENCE_END',
#  u'SENTENCE_START there were many people--men, women, and children--walking about, and these were all dressed in green clothes and had greenish skins. SENTENCE_END',
#  u'SENTENCE_START they looked at dorothy and her strangely assorted company with wondering eyes, and the children all ran away and hid behind their mothers when they saw the lion; but no one spoke to them. SENTENCE_END',
#  u'SENTENCE_START many shops stood in the street, and dorothy saw that everything in them was green. SENTENCE_END',
#  u'SENTENCE_START green candy and green pop corn were offered for sale, as well as green shoes, green hats, and green clothes of all sorts. SENTENCE_END',
#  u'SENTENCE_START at one place a man was selling green lemonade, and when the children bought it dorothy could see that they paid for it with green pennies. SENTENCE_END',
#  u'SENTENCE_START there seemed to be no horses nor animals of any kind; the men carried things around in little green carts, which they pushed before them. SENTENCE_END',
#  u'SENTENCE_START everyone seemed happy and contented and prosperous. SENTENCE_END',
#  u'SENTENCE_START the guardian of the gates led them through the streets until they came to a big building, exactly in the middle of the city, which was the palace of oz, the great wizard. SENTENCE_END',
#  u'SENTENCE_START there was a soldier before the door, dressed in a green uniform and wearing a long green beard. SENTENCE_END',
#  u'SENTENCE_START "here are strangers," said the guardian of the gates to him, "and they demand to see the great oz." SENTENCE_END',
#  u'SENTENCE_START "step inside," answered the soldier, "and i will carry your message to him." SENTENCE_END',
#  u'SENTENCE_START so they passed through the palace gates and were led into a big room with a green carpet and lovely green furniture set with emeralds. SENTENCE_END',
#  u'SENTENCE_START the soldier made them all wipe their feet upon a green mat before entering this room, and when they were seated he said politely:  "please make yourselves comfortable while i go to the door of the throne room and tell oz you are here." SENTENCE_END',
#  u'SENTENCE_START they had to wait a long time before the soldier returned. SENTENCE_END',
#  u'SENTENCE_START when, at last, he came back, dorothy asked:  "have you seen oz?" SENTENCE_END',
#  u'SENTENCE_START "oh, no," returned the soldier; "i have never seen him. SENTENCE_END',
#  u'SENTENCE_START but i spoke to him as he sat behind his screen and gave him your message. SENTENCE_END',
#  u'SENTENCE_START he said he will grant you an audience, if you so desire; but each one of you must enter his presence alone, and he will admit but one each day. SENTENCE_END',
#  u'SENTENCE_START therefore, as you must remain in the palace for several days, i will have you shown to rooms where you may rest in comfort after your journey." SENTENCE_END',
#  ...]

# %%
print 'Parsed %d sentences' % (len(sentences))
# Out:
# Parsed 2223 sentences

# %%
#Tokenize the sentences into words
tokenized_sentences = [nltk.word_tokenize(sent) for sent in sentences]

# %%
#Count word frequency
word_freq = nltk.FreqDist(itertools.chain(*tokenized_sentences))
print 'Found %d unique word tokens' % len(word_freq.items())
# Out:
# Found 2959 unique word tokens

# %%
#Get the most common words and build idx2word and word2idx vectors
vocab = word_freq.most_common(vocabulary_size-1)
idx2word = [x[0] for x in vocab]
idx2word.append(unknown_token)
word2idx = dict([(w,i) for i,w in enumerate(idx2word)])
print 'Using vocabulary size %d' % vocabulary_size
print 'The least frequent word in our vocabulary is "%s" appearing %d times' % (vocab[-1][0], vocab[-1][1])
# Out:
# Using vocabulary size 1500
# The least frequent word in our vocabulary is "hurry" appearing 2 times

# %%
#Replace all words not in our vocabulary with the unknown token
for i,sent in enumerate(tokenized_sentences):
    tokenized_sentences[i] = [w if w in word2idx else unknown_token for w in sent]

# %%
temp = np.random.randint(0, len(sentences))
print 'Example sentence: "%s"\nExample sentence after pre-processing "%s"' % (sentences[temp], tokenized_sentences[temp])
# Out:
# Example sentence: "SENTENCE_START and if he is the great head, he will be at my mercy; for i will roll this head all about the room until he promises to give us what we desire. SENTENCE_END"
# Example sentence after pre-processing "[u'SENTENCE_START', u'and', u'if', u'he', u'is', u'the', u'great', u'head', u',', u'he', u'will', u'be', u'at', u'my', 'UNKNOWN_TOKEN', u';', u'for', u'i', u'will', u'roll', u'this', u'head', u'all', u'about', u'the', u'room', u'until', u'he', u'promises', u'to', u'give', u'us', u'what', u'we', u'desire', u'.', u'SENTENCE_END']"

# %% [markdown]
# ***

# %%
#Create the training data
X_train = np.asarray([[word2idx[w] for w in sent[:-1]] for sent in tokenized_sentences])
y_train = np.asarray([[word2idx[w] for w in sent[1:]] for sent in tokenized_sentences])

# %%
#Training data example
temp = np.random.randint(0, len(sentences))
x_example, y_example = X_train[temp], y_train[temp]
print 'x:\n%s\n%s' % (' '.join([idx2word[x] for x in x_example]), x_example)
print 'y:\n%s\n%s' % (' '.join([idx2word[x] for x in y_example]), y_example)
# Out:
# x:
# SENTENCE_START `` this funny tin man , '' she answered , `` killed the wildcat and saved my life .
# [3, 7, 52, 992, 55, 100, 1, 8, 19, 98, 1, 7, 327, 0, 774, 5, 648, 40, 337, 4]
# y:
# `` this funny tin man , '' she answered , `` killed the wildcat and saved my life . SENTENCE_END
# [7, 52, 992, 55, 100, 1, 8, 19, 98, 1, 7, 327, 0, 774, 5, 648, 40, 337, 4, 2]

# %% [markdown]
# $s_t = $tanh$(Ux_t + Ws_{t-1})$
# $o_t = $softmax$(Vs_t)$
# Let our hidden layer have size $H = 100$
# $x_t \in \mathbb{R}^{1500}$
# $o_t \in \mathbb{R}^{1500}$
# $s_t \in \mathbb{R}^{100}$
# $U \in \mathbb{R}^{100 \times 1500}$
# $V \in \mathbb{R}^{1500 \times 100}$
# $W \in \mathbb{R}^{100 \times 100}$

# %% [markdown]
# #### Initialization

# %%
class RNNNumpy:
    
    def __init__(self, word_dim, hidden_dim=100, bptt_truncate=4):
        self.word_dim = word_dim
        self.hidden_dim = hidden_dim
        self.bptt_truncate = bptt_truncate
        #Random initialization of network parameters in the range [-n**(-1/2), n**(-1/2)]
        self.U = np.random.uniform(-np.sqrt(1./word_dim), np.sqrt(1./word_dim), (hidden_dim, word_dim))
        self.V = np.random.uniform(-np.sqrt(1./hidden_dim), np.sqrt(1./hidden_dim), (word_dim, hidden_dim))
        self.W = np.random.uniform(-np.sqrt(1./hidden_dim), np.sqrt(1./hidden_dim), (hidden_dim, hidden_dim))

# %% [markdown]
# #### Forward Propagation

# %%
def np_softmax(x):
    return np.exp(x) / np.exp(x).sum()

# %%
def forward_propagation(self, x):
    #Total number of time steps
    T = len(x)
    #Save hidden states in s for later
    #Add one additional element for the initial hidden state, set to 0
    s = np.zeros((T + 1, self.hidden_dim))
    s[-1] = np.zeros(self.hidden_dim)
    #Outputs at each time step are saved for later
    o = np.zeros((T, self.word_dim))
    #At each time step
    for t in np.arange(T):
        s[t] = np.tanh(self.U[:,x[t]] + self.W.dot(s[t-1]))
        o[t] = np_softmax(self.V.dot(s[t]))
    return [o, s]

RNNNumpy.forward_propagation = forward_propagation

# %%
def predict(self, x):
    #Perform forward propagation and return index of highest score
    o, s = self.forward_propagation(x)
    return np.argmax(o, axis=1)

RNNNumpy.predict = predict

# %%
#Example output
model = RNNNumpy(vocabulary_size)
o, s = model.forward_propagation(X_train[10])
print o.shape
print o
# Out:
# (50, 1500)
# [[ 0.00067586  0.00067626  0.00067335 ...,  0.00066474  0.0006725
#    0.00066804]
#  [ 0.0006685   0.00066554  0.00066936 ...,  0.00066188  0.0006709
#    0.00067597]
#  [ 0.00066997  0.00066798  0.00065605 ...,  0.00067054  0.00065682
#    0.00066726]
#  ...,
#  [ 0.00067106  0.00066196  0.00066688 ...,  0.00065991  0.00066763
#    0.00066349]
#  [ 0.00066872  0.00065826  0.00067526 ...,  0.000666    0.00067557
#    0.00066162]
#  [ 0.00068957  0.00066697  0.00066813 ...,  0.00066418  0.00068742
#    0.00066253]]

# %%
predictions = model.predict(X_train[10])
print predictions.shape
print predictions
# Out:
# (50,)
# [ 284  786   87  399   63  924   95  999  577 1035   23  110  721 1109  212
#  1228  741 1260 1273  733  875  853  104  345  683 1251  189 1273  938  107
#   870 1219  332  569 1379 1415  935  741 1480 1485  741  581  175  938  605
#   623 1445  746  569  144]

# %%
' '.join([idx2word[i] for i in predictions])
# Out:
# u'started paved did ground could visit now fewer edge rushed as heart quick pure along bend grandfather polished worth careful shut sweet after look known doorway friends worth save your sit flowing although whiskers rising underneath gulf grandfather building condition grandfather rusted some save against bigger ruined kindly whiskers walked'

# %% [markdown]
# #### Calculating Loss

# %%
def calculate_total_loss(self, x, y):
    L = 0
    #For each sentence...
    for i in np.arange(len(y)):
        o, s = self.forward_propagation(x[i])
        #Determine the correct word predictions
        correct_word_predictions = o[np.arange(len(y[i])), y[i]]
        #Add to the loss based on the cross-entropy each term
        L += -1 * np.sum(np.log(correct_word_predictions))
    return L

def calculate_loss(self, x, y):
    #Divide total loss by the number of training examples
    N = np.sum((len(y_i) for y_i in y))
    return self.calculate_total_loss(x,y)/N

RNNNumpy.calculate_total_loss = calculate_total_loss
RNNNumpy.calculate_loss = calculate_loss

# %%
#Loss for 1000 examples
print 'Expected loss for random predictions: %f' % np.log(vocabulary_size)
print 'Actual loss: %f' % model.calculate_loss(X_train[:1000], y_train[:1000])
# Out:
# Expected loss for random predictions: 7.313220
# Actual loss: 7.313423

# %% [markdown]
# #### Training the RNN through SGD and BPTT

# %%
def bptt(self, x, y):
    T = len(y)
    #Perform forward propagation
    o, s = self.forward_propagation(x)
    #Gradient accumulators
    dLdU = np.zeros(self.U.shape)
    dLdV = np.zeros(self.V.shape)
    dLdW = np.zeros(self.W.shape)
    delta_o = o
    delta_o[np.arange(len(y)), y] -= 1
    #For each output, backwards ...
    for t in np.arange(T)[::-1]:
        dLdV += np.outer(delta_o[t], s[t].T)
        #Initial delta
        delta_t = self.V.T.dot(delta_o[t]) * (1 - (s[t] ** 2))
        #Backpropagation through time (for at most self.bptt truncate steps)
        for bptt_step in np.arange(max(0, t-self.bptt_truncate), t+1)[::-1]:
            #print 'Backpropagation step t=%d bptt step=%d' % (t, bptt_step)
            dLdW += np.outer(delta_t, s[bptt_step-1])
            dLdU[:,x[bptt_step]] += delta_t
            #Update delta for next step
            delta_t = self.W.T.dot(delta_t) * (1 - s[bptt_step-1]**2)
    return [dLdU, dLdV, dLdW]

RNNNumpy.bptt = bptt

# %% [markdown]
# #### Gradient Checking

# %%
def gradient_check(self, x, y, h=0.001, error_threshold=0.01):
    #Calculate gradients using backpropagation and check whether that are correct
    bptt_gradients = model.bptt(x, y)
    #Parameters to check
    model_parameters = ['U', 'V', 'W']
    for pidx, pname in enumerate(model_parameters):
        #Get actual parameter value from the model
        parameter = operator.attrgetter(pname)(self)
        print 'Performing gradient check for parameter %s with size %d' % (pname, np.prod(parameter.shape))
        #Iterate over each element of the parameter matrix
        it = np.nditer(parameter, flags=['multi_index'], op_flags=['readwrite'])
        while not it.finished:
            ix = it.multi_index
            #Save original value to be reset to later
            original_value = parameter[ix]
            #Estimate the gradients as (f(x+h) - f(x-h)) / (2*h)
            parameter[ix] = original_value + h
            gradplus = model.calculate_total_loss([x], [y])
            parameter[ix] = original_value - h
            gradminus = model.calculate_total_loss([x], [y])
            estimated_gradient = (gradplus - gradminus) / (2*h)
            #Reset parameter to original value
            parameter[ix] = original_value
            #Calculate the gradient for this parameter with backprop
            backprop_gradient = bptt_gradients[pidx][ix]
            #Calculate the relative error (|x - y| / (|x| + |y|))
            relative_error = np.abs(backprop_gradient - estimated_gradient)/(np.abs(backprop_gradient) + np.abs(estimated_gradient))
            #If the error is too large, then fail the gradient check
            if relative_error > error_threshold:
                print 'Gradient check ERROR: parameter=%s ix=%s' % (pname, ix)
                print '+h loss: %f' % gradplus
                print '-h loss: %f' % gradminus
                print 'Estimated gradient: %f' % estimated_gradient
                print 'Backpropagation gradient: %f' % backprop_gradient
                print 'Relative Error: %f' % relative_error
                return
            it.iternext()
        print 'Gradient check for parameter %s passed' % pname
        
RNNNumpy.gradient_check = gradient_check

# %%
#Check with smaller vocabulary size
grad_check_vocab_size = 100
model = RNNNumpy(grad_check_vocab_size, 10, bptt_truncate=1000)
model.gradient_check([0,1,2,3], [1,2,3,4])
# Out:
# Performing gradient check for parameter U with size 1000
# Gradient check for parameter U passed
# Performing gradient check for parameter V with size 1000
# Gradient check for parameter V passed
# Performing gradient check for parameter W with size 100
# Gradient check for parameter W passed

# %% [markdown]
# #### SGD Implementation

# %% [markdown]
# Two step implementation:
# 1. `sdg_step` calculates the gradients and performs updates for one batch
# 2. Outer loop that iterates through the training set and adjusts the learning rate

# %%
def numpy_sgd_step(self, x, y, learning_rate):
    #Calculate gradients
    dLdU, dLdV, dLdW = self.bptt(x, y)
    #Change parameters according to the gradients and learning rate
    self.U -= learning_rate * dLdU
    self.V -= learning_rate * dLdV
    self.W -= learning_rate * dLdW
    
RNNNumpy.sgd_step = numpy_sgd_step

# %%
def train_with_sdg(model, X_train, y_train, learning_rate=0.005, nepoch=100, evaluate_loss_after=5):
    """Outer SGD Loop
    params:
    X_train: training data set
    y_train: training data targets
    learning_rate: initial learning rate for SGD
    nepoch: number of times to iterate throught the complete data set
    evaluate_loss_after: evaluate the loss after this many epochs"""
    #Keep track of losses
    losses = []
    num_examples_seen = 0
    for epoch in range(nepoch):
        #Optionally evaluate loss
        if (epoch % evaluate_loss_after == 0):
            loss = model.calculate_loss(X_train, y_train)
            losses.append((num_examples_seen, loss))
            time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            print '%s: Loss after num_examples_seen=%d epoch=%d: %f' % (time, num_examples_seen, epoch, loss)
            #Adjust the learning rate, if loss increases
            if (len(losses) > 1 and losses[-1][1] > losses[-2][1]):
                learning_rate = learning_rate * 0.5
                print 'Setting learning rate to %f' % learning_rate
            sys.stdout.flush()
        #For each training example ...
        for i in range(len(y_train)):
            #One SGD step
            model.sgd_step(X_train[i], y_train[i], learning_rate)
            num_examples_seen += 1

# %%
model = RNNNumpy(vocabulary_size)
# %timeit model.sgd_step(X_train[10], y_train[10], 0.005)
# Out:
# 10 loops, best of 3: 37.8 ms per loop

# %%
#Train on a small subset of the data to see what happens
model = RNNNumpy(vocabulary_size)
losses = train_with_sdg(model, X_train[:100], y_train[:100], nepoch=10, evaluate_loss_after=1)
# Out:
# 2018-12-27 10:50:04: Loss after num_examples_seen=0 epoch=0: 7.313290
# 2018-12-27 10:50:06: Loss after num_examples_seen=100 epoch=1: 7.296705
# 2018-12-27 10:50:09: Loss after num_examples_seen=200 epoch=2: 7.251789
# 2018-12-27 10:50:11: Loss after num_examples_seen=300 epoch=3: 5.484497
# 2018-12-27 10:50:13: Loss after num_examples_seen=400 epoch=4: 5.328043
# 2018-12-27 10:50:15: Loss after num_examples_seen=500 epoch=5: 5.243652
# 2018-12-27 10:50:19: Loss after num_examples_seen=600 epoch=6: 5.170964
# 2018-12-27 10:50:22: Loss after num_examples_seen=700 epoch=7: 5.106834
# 2018-12-27 10:50:26: Loss after num_examples_seen=800 epoch=8: 5.065418
# 2018-12-27 10:50:29: Loss after num_examples_seen=900 epoch=9: 5.038469

# %% [markdown]
# #### Training the Network with Theano and the GPU

# %%
import theano as theano
import theano.tensor as T

# %%
class RNNTheano:
    
    def __init__(self, word_dim, hidden_dim=100, bptt_truncate=4):
        # Assign instance variables
        self.word_dim = word_dim
        self.hidden_dim = hidden_dim
        self.bptt_truncate = bptt_truncate
        # Randomly initialize the network parameters
        U = np.random.uniform(-np.sqrt(1./word_dim), np.sqrt(1./word_dim), (hidden_dim, word_dim))
        V = np.random.uniform(-np.sqrt(1./hidden_dim), np.sqrt(1./hidden_dim), (word_dim, hidden_dim))
        W = np.random.uniform(-np.sqrt(1./hidden_dim), np.sqrt(1./hidden_dim), (hidden_dim, hidden_dim))
        # Theano: Created shared variables
        self.U = theano.shared(name='U', value=U.astype(theano.config.floatX))
        self.V = theano.shared(name='V', value=V.astype(theano.config.floatX))
        self.W = theano.shared(name='W', value=W.astype(theano.config.floatX))      
        # We store the Theano graph here
        self.theano = {}
        self.__theano_build__()
    
    def __theano_build__(self):
        U, V, W = self.U, self.V, self.W
        x = T.ivector('x')
        y = T.ivector('y')
        def forward_prop_step(x_t, s_t_prev, U, V, W):
            s_t = T.tanh(U[:,x_t] + W.dot(s_t_prev))
            o_t = T.nnet.softmax(V.dot(s_t))
            return [o_t[0], s_t]
        [o,s], updates = theano.scan(
            forward_prop_step,
            sequences=x,
            outputs_info=[None, dict(initial=T.zeros(self.hidden_dim))],
            non_sequences=[U, V, W],
            truncate_gradient=self.bptt_truncate,
            strict=True)
        
        prediction = T.argmax(o, axis=1)
        o_error = T.sum(T.nnet.categorical_crossentropy(o, y))
        
        # Gradients
        dU = T.grad(o_error, U)
        dV = T.grad(o_error, V)
        dW = T.grad(o_error, W)
        
        # Assign functions
        self.forward_propagation = theano.function([x], o)
        self.predict = theano.function([x], prediction)
        self.ce_error = theano.function([x, y], o_error)
        self.bptt = theano.function([x, y], [dU, dV, dW])
        
        # SGD
        learning_rate = T.scalar('learning_rate')
        self.sgd_step = theano.function([x,y,learning_rate], [], 
                      updates=[(self.U, self.U - learning_rate * dU),
                              (self.V, self.V - learning_rate * dV),
                              (self.W, self.W - learning_rate * dW)])
    
    def calculate_total_loss(self, X, Y):
        return np.sum([self.ce_error(x,y) for x,y in zip(X,Y)])
    
    def calculate_loss(self, X, Y):
        # Divide calculate_loss by the number of words
        num_words = np.sum([len(y) for y in Y])
        return self.calculate_total_loss(X,Y)/float(num_words)   


def gradient_check_theano(model, x, y, h=0.001, error_threshold=0.01):
    # Overwrite the bptt attribute. We need to backpropagate all the way to get the correct gradient
    model.bptt_truncate = 1000
    # Calculate the gradients using backprop
    bptt_gradients = model.bptt(x, y)
    # List of all parameters we want to chec.
    model_parameters = ['U', 'V', 'W']
    # Gradient check for each parameter
    for pidx, pname in enumerate(model_parameters):
        # Get the actual parameter value from the mode, e.g. model.W
        parameter_T = operator.attrgetter(pname)(model)
        parameter = parameter_T.get_value()
        print "Performing gradient check for parameter %s with size %d." % (pname, np.prod(parameter.shape))
        # Iterate over each element of the parameter matrix, e.g. (0,0), (0,1), ...
        it = np.nditer(parameter, flags=['multi_index'], op_flags=['readwrite'])
        while not it.finished:
            ix = it.multi_index
            # Save the original value so we can reset it later
            original_value = parameter[ix]
            # Estimate the gradient using (f(x+h) - f(x-h))/(2*h)
            parameter[ix] = original_value + h
            parameter_T.set_value(parameter)
            gradplus = model.calculate_total_loss([x],[y])
            parameter[ix] = original_value - h
            parameter_T.set_value(parameter)
            gradminus = model.calculate_total_loss([x],[y])
            estimated_gradient = (gradplus - gradminus)/(2*h)
            parameter[ix] = original_value
            parameter_T.set_value(parameter)
            # The gradient for this parameter calculated using backpropagation
            backprop_gradient = bptt_gradients[pidx][ix]
            # calculate The relative error: (|x - y|/(|x| + |y|))
            relative_error = np.abs(backprop_gradient - estimated_gradient)/(np.abs(backprop_gradient) + np.abs(estimated_gradient))
            # If the error is to large fail the gradient check
            if relative_error > error_threshold:
                print "Gradient Check ERROR: parameter=%s ix=%s" % (pname, ix)
                print "+h Loss: %f" % gradplus
                print "-h Loss: %f" % gradminus
                print "Estimated_gradient: %f" % estimated_gradient
                print "Backpropagation gradient: %f" % backprop_gradient
                print "Relative Error: %f" % relative_error
                return 
            it.iternext()
        print "Gradient check for parameter %s passed." % (pname)

# %%
grad_check_vocab_size = 5
model = RNNTheano(grad_check_vocab_size, 10)
gradient_check_theano(model, [0,1,2,3], [1,2,3,4])
# Out:
# Performing gradient check for parameter U with size 50.
# Gradient check for parameter U passed.
# Performing gradient check for parameter V with size 50.
# Gradient check for parameter V passed.
# Performing gradient check for parameter W with size 100.
# Gradient check for parameter W passed.

# %%
model = RNNTheano(vocabulary_size)
# %timeit model.sgd_step(X_train[10], y_train[10], 0.005)
# Out:
# 100 loops, best of 3: 15.8 ms per loop

# %% [markdown]
# ***

# %%
model = RNNTheano(vocabulary_size, hidden_dim=100)
losses = train_with_sdg(model, X_train, y_train, nepoch=100, evaluate_loss_after=10)
# Out:
# 2018-12-27 10:51:16: Loss after num_examples_seen=0 epoch=0: 7.312975
# 2018-12-27 10:55:24: Loss after num_examples_seen=22230 epoch=10: 6.605725
# 2018-12-27 10:59:37: Loss after num_examples_seen=44460 epoch=20: 5.902666
# 2018-12-27 11:03:38: Loss after num_examples_seen=66690 epoch=30: 5.824765
# 2018-12-27 11:07:31: Loss after num_examples_seen=88920 epoch=40: 6.170466
# Setting learning rate to 0.002500
# 2018-12-27 11:11:14: Loss after num_examples_seen=111150 epoch=50: 5.699436
# 2018-12-27 11:14:59: Loss after num_examples_seen=133380 epoch=60: 5.737881
# Setting learning rate to 0.001250
# 2018-12-27 11:18:45: Loss after num_examples_seen=155610 epoch=70: 5.719997
# 2018-12-27 11:22:26: Loss after num_examples_seen=177840 epoch=80: 5.780091
# Setting learning rate to 0.000625
# 2018-12-27 11:26:11: Loss after num_examples_seen=200070 epoch=90: 5.824584
# Setting learning rate to 0.000313

# %% [markdown]
# hidden_dim 50: Takes about 15 minutes, but reached loss of 5.7 after 50 epochs and 8 minutes

# %%
save_model_parameters_theano('data/trained_model_theano.npz', model)
#load_model_parameters_theano('data/trained_model_theano.npz', model)
# Out:
# Saved model parameters to data/trained_model_theano.npz.

# %% [markdown]
# #### Generating Text

# %%
def generate_sentence(model):
    #Begin with the start token
    new_sentence = [word2idx[sentence_start_token]]
    #Repeat until we get an end token
    while not new_sentence[-1] == word2idx[sentence_end_token]:
        next_word_probs = model.forward_propagation(new_sentence)
        sampled_word = word2idx[unknown_token]
        #We don't want to sample unknown words
        while sampled_word == word2idx[unknown_token]:
            samples = np.random.multinomial(1, next_word_probs[-1])
            sampled_word = np.argmax(samples)
        new_sentence.append(sampled_word)
    sentence_str = [idx2word[x] for x in new_sentence[1:-1]]
    return sentence_str

# %%
num_sentences = 10
sentence_min_length = 7

for i in range(num_sentences):
    sent = []
    #We want long sentences
    while len(sent) < sentence_min_length:
        sent = generate_sentence(model)
    print ' '.join(sent)
# Out:
# a princess china little also ? ''
# she asked , his thick ! ''
# she curiosity child her head ? ''
# cried the girl like of do roof .
# she asked , i sorrow out ! ''
# asked dorothy eagerly to kansas . ''
# center back to you thing back ! ''
# asked dorothy lost saw dorothy witch his better .
# hill , in you directions ! ''
# asked the swim lion give her draw .

# %% [markdown]
# Pros:
# * Learned to end sentences with punctuation
# * Learned some adjectives that appear together often, eg tin woodman, little wizard
#
# Cons:
# * Quotation marks do not always end and do not make contextual sense
# * Nonsense sentences, ie there is no context to the word choices

# %%
num_sentences = 20
sentence_min_length = 10

for i in range(num_sentences):
    sent = []
    #We want long sentences
    while len(sent) < sentence_min_length:
        sent = generate_sentence(model)
    print ' '.join(sent)
# Out:
# `` asked not found unhappy green as imagined . ''
# said the farmer in rusted feet perhaps form from the emerald city . ''
# she asked it draw him head and broad it . ''
# asked the lion prairie do and a heart . ''
# tin mouse so glasses in his head green me to it .
# asked the scarecrow lion woman do the wall . ''
# cried dorothy will her our at do good way . ''
# asked dorothy on in had cupboard before ever sadly .
# asked the child woodman chop idle it happy . ''
# asked the milkmaid thoughtfully , with the world of the basket .
# its struck before own were as at the others side . ''
# asked the scarecrow in the cat their clothes . ''
# child the lion to do you would more . ''
# she said dorothy knows there horses to her sorceress .
# she same boq from bad still hair so even .
# good-bye i angrily the clouds trick have evidently her way .
# cried the little in the guarded very with him glinda .
# she asked me of over my head it skins . ''
# asked the farmer anxiously fill you reached and journey upon it leave together .
# answered the princess stopped 's instantly whenever with knocked new disagreeable shoulders .
